# %%
import sys
sys.path.append("/home/shitijkarsolia/Desktop/venvironments/project1/lib/python3.6/site-packages")

# %%
# !pip install utils

# #

# %%
import sys
import keras
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import imutils
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
#from utils import LRN2D
import utils


# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=sys.maxsize)
# Out:
# Using TensorFlow backend.
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from inception_resnet_v1 import *
model = InceptionResNetV1()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0909 18:02:45.038226 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0909 18:02:45.581985 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0909 18:02:45.649109 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0909 18:02:45.770293 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0909 18:02:45.771687 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0909 18:02:46.949071 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0909 18:02:47.247878 140393719252800 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0909 18:02:54.903316 140393719252800 deprecation.py:506] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.load_weights('weights/facenet_weights.h5')
print("weights loaded")
# Out:
# weights loaded

# %%
import traceback
def image_to_embedding(image, model):
    try: 
        
        #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
        image = cv2.resize(image, (160, 160)) 
        img = image[...,::-1]
        img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
        x_train = np.array([img])
        embedding = model.predict_on_batch(x_train)
        return embedding
    except:
        traceback.print_exc()

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
        #knn = KNeighborsClassifier(n_neighbors=1, metric='euclidean')
        #svc = LinearSVC()
        
        #euclidean_distance=np.sum(np.square(embedding-input_embedding))
        #print(type(embedding))
        #print(type(input_embedding))
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
#         a = np.matmul(np.transpose(embedding), input_embedding)
#         b = np.sum(np.multiply(embedding, embedding))
#         c = np.sum(np.multiply(input_embedding, input_embedding))
#         euclidean_distance= 1 - (a / (np.sqrt(b) * np.sqrt(c)))
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 21:
        return str(name)
    else:
        return None

# %%
#This is to make cropped images from the database ( One Time Process)
import glob,cv2,os
import os.path
from os import path
import imutils
import numpy as np
import argparse

# %%
for file in glob.glob("./Employee_Photo/cropped/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        if person_name[0]=='4':
            person_name=person_name.split('_', 1)[-1]
        print(person_name)
# Out:
# Nikhil
# viewPhoto
# image_resize
# resize
# Photo
# Photo
# 081744
# AJAY KUMAR GOND
# 0055
# Manideepa_Pabbathineni(Bangalore)
# size
# gautham
# Photo
# 200
# kristen
# DSC_6418 (2)
# Image
# Bengaluru
# IMG-20190610-WA0006
# resize
# Formal Photo
# KAMAKSHI ANANTHARAMAN
# IMG_20190715_191550
# IMG-20190703-WA0000
# Jibin Philip Raju
# 2253
# resize
# New Doc 2019-07-02 18.23.34_1
# New Doc 2018-10-10 12.30.31 (5)
# resize
# id card
# 1558980574259
# 02
# Anubhav Tiwari (Bangalore)
# zz1
# Nikita Nair 1
# 1.2
# Basmatkar
# 0412
# 131126
# edited
# resize
# nandita
# amritabasurbi
# 01
# jeevan
# Asmita
# resize
# IMG_8040
# 1-1558779272408
# ankita
# photo
# Bangalore
# Photo ID
# Shitij
# 20190723_130020
# New Doc 2018-10-10 12.30.31 (4)
# New Doc 2019-07-02 18.26.28
# IMG-20190602-WA0002
# kishan
# bhalerao
# resize
# Anish Pandita
# Jefrin
# IMG-20190805-WA0022
# sachin
# Debrup_20Photo_20Scan
# Suvan
# new doc 2019-07-03 15.29.27_1
# Photo from Mayank Bhardwaj
# IMG_0874
# ID
# Alka
# 091556
# Amit-passport
# vishakha
# 01
# KarishmaZambare
# New Doc 2018-10-10 12.30.31 (1)
# AdvaitAnilSarang
# 6832
# IMG_20190729_1709329781
# resize
# Anuja_photo
# photo-1555078942270
# IMG_20190703_171118122
# Nayan Dhuri
# pic
# photograph-page-001
# 0
# image_resize
# 04
# New Doc 2018-10-01 18.22.44(2)
# nikesh photo
# 190054
# Passport Picture_1
# Passport Size Photo
# INDRANIL PAUL
# Sneha_Biradar_Photograph
# isa_photo
# a016
# 165404 (1)
# New Doc 2018-10-01 18.22.44 (3)
# Sakshi_Subedi
# photo
# Indore
# Passport
# Avinash Giridhar (Bangalore)
# Ashay Shukla
# ravi
# Nishanth
# Shubham_burned
# Harshesh_Sayani
# resize
# SUNAIN
# edited
# SagarSingh
# Neeraj Passport
# Pujari Sai Vamsi (Bangalore)
# 2018-08-09-09-02-24-009
# ID
# Picture
# Passport Photo
# IMG_20190702_182417~2
# ravindra Passport photo
# New Doc 2019-05-29 09.27.19(1)
# V V CHAKRADHAR (Bangalore)
# Rushikesh Hande
# 1382 copy-1
# 234228
# AkshayaPatil
# image_resize
# Bharmal
# IMG_20190702_225053_ed_SMALL SIZE
# Deepak Moonat
# praful-high-1553525634456
# New Doc 2018-10-10 12.30.31
# photo
# Nilesh Sonawane
# Shubham Rajput
# 112455
# Photo (White Background)
# White Background
# photo
# 01
# 01
# New Doc 2019-06-04 12.42.03[11]
# Toral Divecha_1
# SakshiNatani
# New Doc 2018-10-01 18.22.44(1)
# IMG-20190425-WA0010
# resize
# Saloni Rokde
# 1
# Twisha Saraiya
# 114054
# JaskaranSingh
# Photo
# passportImg
# Sunil Arya
# 13BEE0263
# scan nithya photo
# 184737-02(1)
# WhatsApp Image 2019-05-28 at 12.43.31
# DSC_0256
# IMG_RAYOMAND Y ENGINEER
# Bangalore
# IMG_20190705_103352-min
# Arijit Majumder
# New Doc 2018-10-10 12.30.31(3)
# New Doc 2018-10-01 18.22.44(3)
# IMG-20190822-WA0008
# Yamini Photograph
# Sachin Nath Deora
# image_resize
# Akshat Jain Bangalore
# IMG-4115
# 105844
# 193942
# cropped image
# Devanshi
# 115134
# resize
# New Doc 2018-10-01 18.22.44 (5)
# img
# 3
# Varun
# IMG_20190702_145649
# IMG_20190522_172847__01
# New Doc 2019-06-10 12.17.47
# Fz
# image_resize
# pic
# Arthi Kailash
# K Prashanth Kumar (Bangalore)
# photograph
# file-4
# Malavika5
# Joshua_Almeida_Picture_BA
# SHubham
# 230609
# Akanksha Vora
# New Doc 2019-04-02 16.56.29
# PrashantSaive
# Debasmita Dasgupta
# resize
# 174116[1]
# Mohsin Khan (Bangalore)
# Swapnil Bera Bangalore
# IMG-20190703-WA0000
# photo-1555912899664
# Divyesh Bohra
# WhatsApp Image 2019-05-28 at 11.03.50 AM
# pallavi_kadam
# sandesh
# sumit-parasmal-jain-bro-vasai-5
# 20190702_182629
# WhatsApp Image 2019-05-29 at 5.19.07 PM
# Anubhav Kar
# Vaibhav Agarwal - Q0614
# 175127
# krutik_menkudle
# New Doc 2018-10-01 18.22.44 (2)
# resize
# 1
# 1 (3)
# PHOTO-2019-07-24-19-08-20
# vinit
# Divya Dinesh Thottiparambil
# resize
# IMG_20190729_165945__01
# 0164ab
# IMG20190702215815
# SPIT
# Akshat Shetty
# YashrajGangalPhotograph
# 184901
# Passport Photo
# 01
# Abhinav Thakur
# New Doc 2019-04-16 10.55.36
# Kumar
# DSC0045
# FB_IMG_1561369648764
# ANKESH PATIL
# 182801
# Gaurav Vashishtha - Bangalore
# Katta Abhishek Bangalore
# Photo
# Bangalore
# mj
# NMIMS
# Manjunath Bangalore
# HDR
# Asmiriti_Kumari_Photograph_AIT_Pune
# image_resize
# IMG_20190429_130317_030
# IMG-20190702-WA0005
# saurabh roy
# Gupta(Bangalore)
# IMG_20190702_182330
# 80
# 943
# New Doc 2018-10-10 12.30.31 (9)
# 01
# 1
# 3
# Himani
# rahulkumarsinghbangalore
# PHOTO
# AsthaJain
# IMG_20181114_185939__01
# scan_pic
# Apurv Gupta
# Prakash ID photo
# 8-Saurabh-1x1
# 2018-09-17-09-14-29
# Avinash Sidhwani
# mypic
# Abd
# LEKHANA
# 118-AVINAV
# IMG_20180321_221006 (1)
# Vaibhav
# New Doc 2018-10-10 12.30.31(2)
# Abhishek Jha
# Official
# Arun Chandhar Ravi (Bangalore)
# Screenshot_20190805-193339__01
# resize
# 01
# n
# cfad876a-7482-4a7b-981d-6b6f1a765e4a
# Photograph passport size
# New Doc 2018-10-10 12.30.31(1)
# image_resize
# Photo
# PHOTO-2019-07-04-22-02-30
# 16004
# Screenshot_20190723-085220__01
# SrashtiDhakad
# photo-1557862443929
# Shubham Mukherjee
# 1
# 01
# 02
# resize
# Parag Sharma
# krutika
# Sriharsha B S Prasad Bangalore
# PassportSize-29.05.2019
# resize
# FB_IMG_1550894132150
# 2
# MelburneRodrigues
# Passport Photo
# resize
# Yash_Mehta_whitebackground
# 182020
# n (1)
# 8558
# Vivek Photo
# 102731719
# 08 - photograph
# image_resize
# image_resize
# New Doc 2018-10-01 18.22.44
# New Doc 2018-10-01 18.22.44(4)
# 2
# 104607
# WhatsApp Image 2019-06-04 at 12.55.15 PM
# PassportSize
# Kanchan Rawat
# 01
# 1
# scan nithya photo
# Bangalore
# prem
# PHOTO
# 1a
# 0
# 1.1
# aishwarya(Bangalore)
# sanyogita
# photo
# Ajad
# Ritesh Joseph
# Pawar
# Pic
# PassportSize
# Ayush
# resize
# A4 size pic
# Sarath kumar Tamminana
# passportsize-1547968705966
# 000015-01
# 095142
# 1
# Quantiphi photo
# patil
# 1-1
# Rishi
# image_resize
# New Doc 2018-10-01 18.22.44 (9)
# Pic
# 118-AVINAV
# Photo 1
# Tanmay_Parulekar
# 4
# image_resize
# preview 1
# New Doc 2018-10-10 12.30.31(4)
# PicsArt_06-15-12.55.51
# 17469
# 7497
# 1
# pradeep
# Passport
# 21
# Mrutyunjay Hiremath
# 194533
# Sohail Anwar- Bangalore
# 2
# IMG-5871
# Shivani
# resize
# 1
# 0
# scan0044
# 141456B4-CB2D-464A-AB0A-094B980DC0E3
# Piyush Profile Pic
# New Doc 2018-10-01 18.22.44 (7)
# 807
# Maitri_Fafadia_PhotoGraph_DJSCE
# New Doc 2018-10-10 12.30.31 (8)
# 16
# Felicia Photograph
# IMG
# resize
# pic
# ritvik joshi
# 2
# Photo
# mypic
# New Doc 2018-10-01 18.22.44 (4)
# Aradhana_Pandey_Photograph_VNIT_Nagpur
# mohit bhalodia
# Austin Dsouza
# Sathish Krishnan (Bangalore)
# quantiphi
# 1
# Musaveer A Holalkere Bangalore
# jash_shah_DE
# IMG20190601132155
# Ameet Choudhary
# Millennium Bismay (Bangalore)
# 6920 copy
# unnamed
# white
# Brahmankar(Sinkar)
# Amit Kumar Ram
# Ankita_Vaidya
# 01
# ashish_pic
# Rahul Kandari - 1288
# passport photo
# FullSizeRender-min
# White Background
# Shivam.Singh
# karthik shathiri (bengaluru)
# resize
# Vishal Waghmare
# Anand Santosh Jha
# Balapanuru
# HARSHITA
# IMG-20190729-WA0010
# PASSPORT SIZE PHOTO
# 185655
# Pic with White BG
# SushanthD_Bangalore
# 32 AM Office Lens
# jogdand
# 399
# V Subbaiah Bangalore
# DSC_0145
# Mustufahasan Shabbir Surti
# Shobha
# n
# 15040-115
# photo
# IMG-20190507-WA0002
# risheekesh
# New Doc 2018-10-10 12.30.31 (2)
# Disha_Shetty_Photo_PCCOE
# PP
# Bangalore
# PhotoGrid_1562071481388
# Ketan S Palankar Bangalore
# whiteback
# WhatsApp Image 2019-06-08 at 17.52.25
# IMG_20190703_105824
# 0007 - Copy
# Parvati
# Sai Appala Raju I (Banglore)
# kavish mehta(Bangalore)
# pereira
# Akash
# Photo ID white BG
# Photo
# cat-baby-khushboo-sahu
# WhatsApp Image 2019-08-28 at 10.53.50 AM
# IIFT
# 161615
# 111717
# Ketav
# Bengaluru
# Gaurav Maniyar
# ipg_2014074
# bangalore
# New Doc 2018-10-10 12.30.31 (3)
# image_resize
# Gail Cardozo
# 103518
# image_resize
# New Doc 2019-07-03 12.15.08
# 1
# Vasant_Mahadik_Passport Size Photo
# Hitesh(Bangalore)
# Vasu(Bangalore)
# 182940
# IMG_20190716_150042
# Passport Photo (2019.03.31) - Rijul Raut
# photo
# card
# 200101
# IMG_20190702_225008__01
# Krunal photo-1
# img048
# 869
# Mishall_Swain
# Bangalore
# resize
# Suraj_Bangalore
# Rituparna adha_bengaluru
# photo
# arvind
# Ashutosh Patidar
# New Doc 2018-10-10 12.30.31 (7)
# Bangalore
# linked
# 7462
# pic
# Patil_Siddhant_Vitthal
# 154936
# image_resize
# Arjun picv
# Bharat
# Ankit Goyal
# passport photo
# Solanki
# Subhankar Pati(Bangalore)
# Abhijeet.Tarale Bangalore
# 101436
# Yaramala.Spandana(Bangalore)
# unnamed
# IMG-20190530-WA0009
# 1
# Osheen
# New Doc 2018-10-10 12.30.31 (6)
# Kamal
# pic
# ArchID
# Debasmita Dasgupta
# PHOTO
# New Doc 2018-10-01 18.22.44 (8)
# Shivam.Singh
# Image
# Pooja Sharma
# Vijay Mannur
# MANGALEKAR
# AkankshaJoshi
# engineering-1547745743836
# photo
# 2018-09-05-20-55-01-852
# Neelesh Yadav Bangalore
# image_resize
# NidhiJain(Banglore)
# photo-1553354936430
# varghese
# formal pic
# Nazmeen copy
# 1
# 00
# 7619
# AqibImage - Copy
# prakshal
# Photograph
# KabirSachdevImage
# 59.152.53.203(optimized)
# image_resize
# 01
# resize
# shrutichoudhari
# 20190816_082257
# 7008
# ramkumar
# swaroop
# passport size photo - Mudita Sisodia
# 20190703_154159
# karan photo
# Shashwath
# Vridhi Shah
# Bangalore
# Divya Pascal (Bangalore)
# picture
# Shekhar Bhalsing
# AravindMenon(Bangalore)
# Karukonda_Nikhil_Reddy(Bangalore)
# Passport Pic
# IMG-20161121-WA0046
# o
# pic
# Mokshadayini Narsule
# white
# image_resize
# SPIT
# Shubhada-Padwal-Passport-Photo-1
# Bhavesh
# resize
# 1
# 9809e056-4973-4a95-a2ea-7f6909afaf7b
# 1
# New Doc 2018-10-01 18.22.44 (6)
# AyushBahuguna(Bangalore)
# Amit_Deshwal_SD
# DSC0051 copy 2
# New Doc 2019-05-29 10.40.02
# 1.PHOTO
# Photo-1
# AkshayWagh
# download
# New Doc 2018-10-01 18.22.44 (1)
# New Doc 2018-09-30 21.25.49
# KaustubhMaheshKhavnekar
# 2
# photo-1
# resize
# Photograph
# 115429
# IMG_20171029_143708_01_01_01
# viewer
# 165154-min
# image_resize
# image_resize
# Tejas_20Ved
# 2
# Palash
# 01
# 234041
# 8thsep
# Sumi Neogi
# Khyati_20Parashar
# Abhishek Patra, Bangalore

# %%
# import cv2
import glob,os

prototxt="./deploy.prototxt.txt"
model_det_crop="./res10_300x300_ssd_iter_140000.caffemodel"
# confidence_ref=0.5
net = cv2.dnn.readNetFromCaffe(prototxt, model_det_crop)
count=0
for file in glob.glob("/home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/*"):
    person_name = os.path.splitext(os.path.basename(file))[0]
    print(person_name)
    print(file)
    image=cv2.imread(file)
# for image in images:
    
#     image = cv2.imread(image)
    count=count+1
    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0,
        (300, 300), (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the detections and
    # predictions
#     print("[INFO] computing object detections...")
    net.setInput(blob)
    detections = net.forward()

    # loop over the detections
    for i in range(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with the
        # prediction
        confidence = detections[0, 0, i, 2]

        # filter out weak detections by ensuring the `confidence` is
        # greater than the minimum confidence
        if confidence > 0.6:
            # compute the (x, y)-coordinates of the bounding box for the
            # object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
#             count=count+1
            # draw the bounding box of the face along with the associated
            # probability
            text = "{:.2f}%".format(confidence * 100)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            #cv2.rectangle(image, (startX, startY), (endX, endY),
              #  (0, 0, 255), 2)
    #         cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
#             cv2.rectangle(image, (startX, startY), (endX, endY),
#                 (0, 0, 255), 2)
    #         cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     

            #cv2.putText(image, text, (startX, y),
            #    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
#             cv2.imwrite("images/User_" + str(count) + ".jpg", image[startY:endY,startX:endX])
            if not path.exists("/home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/cropped/"+person_name+".jpg"):
                cv2.imwrite("/home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/cropped/"+person_name+".jpg", image[startY:endY,startX:endX])
            #else:
              #  cv2.imwrite("Employee_Photo/cropped/"+person_name+str(count)+".jpg", image[startY:endY,startX:endX])
# Out:
# Ayush Gupta
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Ayush Gupta.jpg
# Sagar Kewalramani
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Sagar Kewalramani.jpg
# Madhura Vijay Gore
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Madhura Vijay Gore.jpg
# Shobha Mangaonkar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Shobha Mangaonkar.jpg
# Mohit Aggarwal
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Mohit Aggarwal.jpg
# Abhinav Abhishek
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Abhinav Abhishek.jpg
# Parul Saraswat
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Parul Saraswat.jpg
# Reshma Katkar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Reshma Katkar.jpg
# Maitri Gosalia
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Maitri Gosalia.jpg
# Sanjeev Janagill
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Sanjeev Janagill.png
# Aryaman Kothari
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Aryaman Kothari.jpg
# Sumit Jain
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Sumit Jain.jpg
# Krutik Menkudle
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Krutik Menkudle.jpg
# Nilesh Sonawane
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Nilesh Sonawane.jpg
# Krunal P Mandani
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Krunal P Mandani.jpg
# Indresh Kumar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Indresh Kumar.png
# Satish Kumar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Satish Kumar.jpg
# Komal Varadkar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Komal Varadkar.jpg
# Bhavesh Sadhwani
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Bhavesh Sadhwani.jpg
# Priyanka Chauhan
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Priyanka Chauhan.jpg
# Abhijeet Arvindrao Burde
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Abhijeet Arvindrao Burde.jpg
# Rushali Patil
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Rushali Patil.jpg
# Nikesh Shah
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Nikesh Shah.jpg
# Sabhyata Shukla
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Sabhyata Shukla.jpg
# Achin Saharawat
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/

# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Ashutosh Patidar.jpg
# Nidhi Prabhu Dabholkar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Nidhi Prabhu Dabholkar.jpg
# Bharat Patidar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Bharat Patidar.jpg
# Mili Gandhi
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Mili Gandhi.jpg
# Neil Anand Singh
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Neil Anand Singh.jpg
# Mohsin Khan
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Mohsin Khan.jpg
# Ankur Govil
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Ankur Govil.jpg
# Abhijeet Tarale
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Abhijeet Tarale.jpg
# Baby Khushboo Sahu
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Baby Khushboo Sahu.jpg
# Surbhi Gangwal
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Surbhi Gangwal.png
# Bhavisha V Mansukhani
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Bhavisha V Mansukhani.jpg
# Ashish Tulsankar
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Ashish Tulsankar.png
# Aslam Yunusbhai Shrimali
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Aslam Yunusbhai Shrimali.jpg
# Ayush Gupta1
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Ayush Gupta1.jpg
# Pranjal Jain
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Pranjal Jain.jpg
# Dharmil Shah
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Dharmil Shah.jpg
# Dimpal Jayani
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Dimpal Jayani.jpg
# Akash S
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Akash S.jpg
# Hina Agrawal
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Hina Agrawal.jpg
# Henry Deva P Thathapudi
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Henry Deva P Thathapudi.jpg
# Aditi Gangrade
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Aditi Gangrade.jpg
# Nagendra Karthik Nagamangalam
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Nagendra Karthik Nagamangalam.jpg
# Vinit Dabake
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Vinit Dabake.jpg
# Eshan Tyagi
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Eshan Tyagi.jpg
# Himanshu Rathore
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Himanshu Rathore.png
# Rama Kandimalla
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Rama Kandimalla.jpg
# Samrudhi Madre
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Samrudhi Madre.jpg
# Kolli Madhava Reddy
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Kolli Madhava Reddy.jpg
# Janesar Ahemad
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Janesar Ahemad.jpg
# Gowna M
# /home/shitijkarsolia/Desktop/projects/Siamese/Working_Code/combinedall/Gowna M.jpg

# %%
#This is to create embeddings from the croppd images in database( One time process)
import glob
import time
import numpy as np
import argparse
import cv2
import traceback
def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("./Employee_Photo/cropped/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        if person_name[0]=='4':
            person_name=person_name.split('_', 1)[-1]
        image_file = cv2.imread(file, 1)
#         face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#         faces = face_detector.detectMultiScale(image_file, 1.3, 5)
#         for (x,y,w,h) in faces:
#             x1 = x
#             y1 = y
#             x2 = x+w
#             y2 = y+h
#             cv2.rectangle(image_file, (x1,y1), (x2,y2), (255,255,255), 2)
#             cv2.imwrite("cropped/"+person_name + ".jpg", image_file[y1:y2,x1:x2])
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    
    prototxt="./deploy.prototxt.txt"
    det_model="./res10_300x300_ssd_iter_140000.caffemodel"
    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(1)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    #face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    

# # construct the argument parse and parse the arguments
#     ap = argparse.ArgumentParser()
#    # ap.add_argument("-i", "--image", required=True,
#         #help="path to input image")
# #     ap.add_argument("-p", "--prototxt",default="/home/kamal-keswani/Desktop/FaceRec_Attendence_Quantiphi/Test2_Notebook",
# #         help="path to Caffe 'deploy' prototxt file")
# #     ap.add_argument("-m", "--model", default="/home/kamal-keswani/Desktop/FaceRec_Attendence_Quantiphi/Test2_Notebook",
# #         help="path to Caffe pre-trained model")
#     ap.add_argument("-c", "--confidence", type=float, default=0.5,
#         help="minimum probability to filter weak detections")
#     args = vars(ap.parse_args())
    print("[INFO] loading model...")
    net = cv2.dnn.readNetFromCaffe(prototxt, det_model)
    
    while vc.isOpened():
        _, frame = vc.read()
        img=frame
        frame = imutils.resize(frame, width=600)
 
        # grab the frame dimensions and convert it to a blob
        (h, w) = frame.shape[:2]
        blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0,
            (300, 300), (104.0, 177.0, 123.0))
 
	# pass the blob through the network and obtain the detections and
	# predictions
        net.setInput(blob)
        detections = net.forward()
        time1= time.time()
        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      

        # Loop through all the faces detected 
        identities = []
        for i in range(0, detections.shape[2]):
            # extract the confidence (i.e., probability) associated with the
            # prediction
            confidence = detections[0, 0, i, 2]

            # filter out weak detections by ensuring the `confidence` is
            # greater than the minimum confidence
            if confidence < 0.5:
                continue

            # compute the (x, y)-coordinates of the bounding box for the
            # object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

           
            
            face_image = frame[max(0, startY):min(h, endY), max(0, startX):min(w, endX)]   
            # face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            time2= time.time()
            print("Time Taken : ", time2-time1)
            text = "{:.2f}%".format(confidence * 100)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            img=cv2.rectangle(frame, (startX, startY), (endX, endY),
                (0, 0, 255), 2)
            #img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
    
            if identity is not None:
                cv2.putText(img, str(identity), (startX+5,startY-5), font, 1, (0,0,255), 2)
                #cv2.putText(frame, text, (startX, y),
                 #   cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
        
#         frame = imutils.resize(img, width=800)
        key = cv2.waitKey(1)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %%
input_embeddings = create_input_image_embeddings()

# %%
recognize_faces_in_cam(input_embeddings)
# Out:
# [INFO] loading model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-06c3d0eeb950> in <module>
# ----> 1 recognize_faces_in_cam(input_embeddings)
#
# <ipython-input-28-4b9d1b3e2a2b> in recognize_faces_in_cam(input_embeddings)
#      94             face_image = frame[max(0, startY):min(h, endY), max(0, startX):min(w, endX)]
#      95             # face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]
# ---> 96             identity = recognize_face(face_image, input_embeddings, model)
#      97
#      98             time2= time.time()
#
# <ipython-input-30-c2a56a7d6239> in recognize_face(face_image, input_embeddings, model)
#      15         #print(type(embedding))
#      16         #print(type(input_embedding))
# ---> 17         euclidean_distance = np.linalg.norm(vector(embedding)-vector(input_embedding))
#      18 #         a = np.matmul(np.transpose(embedding), input_embedding)
#      19 #         b = np.sum(np.multiply(embedding, embedding))
#
# NameError: name 'vector' is not defined
