# %%
import sys
sys.path.append("/home/shitijkarsolia/Desktop/venvironments/project1/lib/python3.6/site-packages")

# %%
# !pip install utils

# #

# %%
import sys
import keras
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import imutils
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
#from utils import LRN2D
import utils


# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=sys.maxsize)
# Out:
# Using TensorFlow backend.
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from inception_resnet_v1 import *
model = InceptionResNetV1()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0913 12:23:02.655467 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0913 12:23:03.130718 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0913 12:23:03.198863 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0913 12:23:03.325808 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0913 12:23:03.326918 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0913 12:23:04.310719 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0913 12:23:04.573202 139649963976512 deprecation_wrapper.py:119] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0913 12:23:12.960747 139649963976512 deprecation.py:506] From /home/shitijkarsolia/Desktop/projects/Siamese/snn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.load_weights('weights/facenet_weights.h5')
print("weights loaded")
# Out:
# weights loaded

# %%
import traceback
def image_to_embedding(image, model):
    try: 
        
        #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
        image = cv2.resize(image, (160, 160)) 
        img = image[...,::-1]
        img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
        x_train = np.array([img])
        embedding = model.predict_on_batch(x_train)
        return embedding
    except:
        traceback.print_exc()

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
        #knn = KNeighborsClassifier(n_neighbors=1, metric='euclidean')
        #svc = LinearSVC()
        
        #euclidean_distance=np.sum(np.square(embedding-input_embedding))
        #print(type(embedding))
        #print(type(input_embedding))
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
#         a = np.matmul(np.transpose(embedding), input_embedding)
#         b = np.sum(np.multiply(embedding, embedding))
#         c = np.sum(np.multiply(input_embedding, input_embedding))
#         euclidean_distance= 1 - (a / (np.sqrt(b) * np.sqrt(c)))
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 21:
        return str(name)
    else:
        return None

# %%
#This is to make cropped images from the database ( One Time Process)
import glob,cv2,os
import os.path
from os import path
import imutils
import numpy as np
import argparse

# import cv2
prototxt="./deploy.prototxt.txt"
model_det_crop="./res10_300x300_ssd_iter_140000.caffemodel"
# confidence_ref=0.5
net = cv2.dnn.readNetFromCaffe(prototxt, model_det_crop)
count=0
for file in glob.glob("./Employee_Photo/*.jp*g"):
    person_name = os.path.splitext(os.path.basename(file))[0]
    print(person_name)
    print(file)
    image=cv2.imread(file)
# for image in images:
    
#     image = cv2.imread(image)
    count=count+1
    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0,
        (300, 300), (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the detections and
    # predictions
#     print("[INFO] computing object detections...")
    net.setInput(blob)
    detections = net.forward()

    # loop over the detections
    for i in range(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with the
        # prediction
        confidence = detections[0, 0, i, 2]

        # filter out weak detections by ensuring the `confidence` is
        # greater than the minimum confidence
        if confidence > 0.6:
            # compute the (x, y)-coordinates of the bounding box for the
            # object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
#             count=count+1
            # draw the bounding box of the face along with the associated
            # probability
            text = "{:.2f}%".format(confidence * 100)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            #cv2.rectangle(image, (startX, startY), (endX, endY),
              #  (0, 0, 255), 2)
    #         cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
#             cv2.rectangle(image, (startX, startY), (endX, endY),
#                 (0, 0, 255), 2)
    #         cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     

            #cv2.putText(image, text, (startX, y),
            #    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
#             cv2.imwrite("images/User_" + str(count) + ".jpg", image[startY:endY,startX:endX])
            if not path.exists("Employee_Photo/cropped/"+person_name+".jpg"):
                cv2.imwrite("Employee_Photo/cropped/"+person_name+".jpg", image[startY:endY,startX:endX])
            #else:
              #  cv2.imwrite("Employee_Photo/cropped/"+person_name+str(count)+".jpg", image[startY:endY,startX:endX])

# %%
#This is to create embeddings from the croppd images in database( One time process)
import glob
import time
import numpy as np
import argparse
import cv2
import traceback
def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("./Employee_Photo/cropped/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        if person_name[0]=='4':
            person_name=person_name.split('_', 1)[-1]
        image_file = cv2.imread(file, 1)
#         face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#         faces = face_detector.detectMultiScale(image_file, 1.3, 5)
#         for (x,y,w,h) in faces:
#             x1 = x
#             y1 = y
#             x2 = x+w
#             y2 = y+h
#             cv2.rectangle(image_file, (x1,y1), (x2,y2), (255,255,255), 2)
#             cv2.imwrite("cropped/"+person_name + ".jpg", image_file[y1:y2,x1:x2])
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    
    prototxt="./deploy.prototxt.txt"
    det_model="./res10_300x300_ssd_iter_140000.caffemodel"
    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(1)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    #face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    

# # construct the argument parse and parse the arguments
#     ap = argparse.ArgumentParser()
#    # ap.add_argument("-i", "--image", required=True,
#         #help="path to input image")
# #     ap.add_argument("-p", "--prototxt",default="/home/kamal-keswani/Desktop/FaceRec_Attendence_Quantiphi/Test2_Notebook",
# #         help="path to Caffe 'deploy' prototxt file")
# #     ap.add_argument("-m", "--model", default="/home/kamal-keswani/Desktop/FaceRec_Attendence_Quantiphi/Test2_Notebook",
# #         help="path to Caffe pre-trained model")
#     ap.add_argument("-c", "--confidence", type=float, default=0.5,
#         help="minimum probability to filter weak detections")
#     args = vars(ap.parse_args())
    print("[INFO] loading model...")
    net = cv2.dnn.readNetFromCaffe(prototxt, det_model)
    process_this_frame = True

    while vc.isOpened():
        _, frame = vc.read()
       
        img=frame
#         frame = imutils.resize(frame, width=600)
 
        # grab the frame dimensions and convert it to a blob
        (h, w) = frame.shape[:2]
        blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0,
            (300, 300), (104.0, 177.0, 123.0))
 
	# pass the blob through the network and obtain the detections and
	# predictions
        net.setInput(blob)
        detections = net.forward()
        time1= time.time()
        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      

        # Loop through all the faces detected 
        identities = []
        for i in range(0, detections.shape[2]):
            # extract the confidence (i.e., probability) associated with the
            # prediction
            confidence = detections[0, 0, i, 2]

            # filter out weak detections by ensuring the `confidence` is
            # greater than the minimum confidence
            if confidence < 0.5:
                continue

            # compute the (x, y)-coordinates of the bounding box for the
            # object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

           
            
            face_image = frame[max(0, startY):min(h, endY), max(0, startX):min(w, endX)]   
            # face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            time2= time.time()
            print("Time Taken : ", time2-time1)
            text = "{:.2f}%".format(confidence * 100)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            img=cv2.rectangle(frame, (startX, startY), (endX, endY),
                (0, 0, 255), 2)
            #img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
    
            if identity is not None:
                cv2.putText(img, str(identity), (startX+5,startY-5), font, 1, (0,0,255), 2)
                #cv2.putText(frame, text, (startX, y),
                 #   cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
        
#         frame = imutils.resize(img, width=800)
        key = cv2.waitKey(1)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %%
input_embeddings = create_input_image_embeddings()

# %%
recognize_faces_in_cam(input_embeddings)
# Out:
# [INFO] loading model...
# Euclidean distance from Nikhil is 11.292478
# Euclidean distance from viewPhoto is 11.557731
# Euclidean distance from image_resize is 11.668259
# Euclidean distance from resize is 12.206245
# Euclidean distance from Photo is 13.8319235
# Euclidean distance from 081744 is 12.256037
# Euclidean distance from AJAY KUMAR GOND is 11.782568
# Euclidean distance from 0055 is 12.534381
# Euclidean distance from Manideepa_Pabbathineni(Bangalore) is 10.952466
# Euclidean distance from size is 11.983341
# Euclidean distance from gautham is 11.990884
# Euclidean distance from 200 is 10.282575
# Euclidean distance from kristen is 10.8897705
# Euclidean distance from DSC_6418 (2) is 11.365682
# Euclidean distance from Image is 12.218221
# Euclidean distance from Bengaluru is 11.87617
# Euclidean distance from IMG-20190610-WA0006 is 10.614311
# Euclidean distance from Formal Photo is 11.913463
# Euclidean distance from KAMAKSHI ANANTHARAMAN  is 12.409165
# Euclidean distance from IMG_20190715_191550 is 13.284015
# Euclidean distance from IMG-20190703-WA0000 is 11.051603
# Euclidean distance from Jibin Philip Raju is 12.698929
# Euclidean distance from 2253 is 11.565221
# Euclidean distance from New Doc 2019-07-02 18.23.34_1 is 11.108475
# Euclidean distance from New Doc 2018-10-10 12.30.31 (5) is 12.24502
# Euclidean distance from id card is 11.57204
# Euclidean distance from 1558980574259 is 12.548497
# Euclidean distance from 02 is 11.250588
# Euclidean distance from Anubhav Tiwari (Bangalore) is 10.026947
# Euclidean distance from zz1 is 9.731914
# Euclidean distance from Nikita Nair 1 is 13.56078
# Euclidean distance from 1.2 is 12.023142
# Euclidean distance from Basmatkar is 11.555488
# Euclidean distance from 0412 is 11.516101
# Euclidean distance from 131126 is 11.866291
# Euclidean distance from edited is 11.735279
# Euclidean distance from nandita is 10.895561
# Euclidean distance from amritabasurbi is 12.564286
# Euclidean distance from 01 is 11.735447
# Euclidean distance from jeevan is 12.537102
# Euclidean distance from Asmita is 12.2475195
# Euclidean distance from IMG_8040 is 11.184947
# Euclidean distance from 1-1558779272408 is 11.900636
# Euclidean distance from ankita is 12.484364
# Euclidean distance from photo is 11.359351
# Euclidean distance from Bangalore is 12.247174
# Euclidean distance from Photo ID is 12.81567
# Euclidean distance from Shitij is 11.570273
# Euclidean distance from 20190723_130020 is 13.425327
# Euclidean distance from New Doc 2018-10-10 12.30.31 (4) is 12.24502
# Euclidean distance from New Doc 2019-07-02 18.26.28 is 9.9022255
# Euclidean distance from IMG-20190602-WA0002 is 11.627364
# Euclidean distance from kishan is 12.854652
# Euclidean distance from bhalerao is 12.4486885
# Euclidean distance from Anish Pandita is 12.683437
# Euclidean distance from Jefrin is 11.7292595
# Euclidean distance from IMG-20190805-WA0022 is 11.074728
# Euclidean distance from sachin is 10.943098
# Euclidean distance from Debrup_20Photo_20Scan is 11.58357
# Euclidean distance from Suvan is 10.828684
# Euclidean distance from new doc 2019-07-03 15.29.27_1 is 11.569081
# Euclidean distance from Photo from Mayank Bhardwaj is 12.468541
# Euclidean distance from IMG_0874 is 11.049569
# Euclidean distance from ID is 11.369432
# Euclidean distance from Alka is 11.723599
# Euclidean distance from 091556 is 13.388403
# Euclidean distance from Amit-passport is 11.202351
# Euclidean distance from vishakha is 12.350545
# Euclidean distance from KarishmaZambare is 11.595926
# Euclidean distance from New Doc 2018-10-10 12.30.31 (1) is 12.24502
# Euclidean distance from AdvaitAnilSarang is 11.466959
# Euclidean distance from 6832 is 11.1482725
# Euclidean distance from IMG_20190729_1709329781 is 11.46123
# Euclidean distance from Anuja_photo is 11.283793
# Euclidean distance from photo-1555078942270 is 10.769797
# Euclidean distance from IMG_20190703_171118122 is 13.17792
# Euclidean distance from Nayan Dhuri is 11.81196
# Euclidean distance from pic is 11.766569
# Euclidean distance from photograph-page-001 is 10.14164
# Euclidean distance from 0 is 11.855007
# Euclidean distance from 04 is 12.008796
# Euclidean distance from New Doc 2018-10-01 18.22.44(2) is 11.015143
# Euclidean distance from nikesh photo is 12.35034
# Euclidean distance from 190054 is 11.819014
# Euclidean distance from Passport Picture_1 is 12.581934
# Euclidean distance from Passport Size Photo is 11.623902
# Euclidean distance from INDRANIL PAUL is 10.65781
# Euclidean distance from Sneha_Biradar_Photograph is 12.206898
# Euclidean distance from isa_photo is 11.400162
# Euclidean distance from a016 is 11.121921
# Euclidean distance from 165404 (1) is 12.713854
# Euclidean distance from New Doc 2018-10-01 18.22.44 (3) is 11.015143
# Euclidean distance from Sakshi_Subedi is 12.696684
# Euclidean distance from Indore is 12.7507925
# Euclidean distance from Passport is 11.666188
# Euclidean distance from Avinash Giridhar (Bangalore) is 11.863399
# Euclidean distance from Ashay Shukla is 11.929579
# Euclidean distance from ravi is 12.219017
# Euclidean distance from Nishanth is 11.119287
# Euclidean distance from Shubham_burned is 11.226234
# Euclidean distance from Harshesh_Sayani is 11.198714
# Euclidean distance from SUNAIN is 12.77122
# Euclidean distance from SagarSingh is 11.934714
# Euclidean distance from Neeraj Passport is 11.306597
# Euclidean distance from Pujari Sai Vamsi (Bangalore) is 11.155518
# Euclidean distance from 2018-08-09-09-02-24-009 is 12.703901
# Euclidean distance from Picture is 12.068471
# Euclidean distance from Passport Photo is 11.998193
# Euclidean distance from IMG_20190702_182417~2 is 12.265628
# Euclidean distance from ravindra Passport photo is 12.042316
# Euclidean distance from New Doc 2019-05-29 09.27.19(1) is 12.158943
# Euclidean distance from V V CHAKRADHAR (Bangalore) is 11.450968
# Euclidean distance from Rushikesh Hande is 12.55098
# Euclidean distance from 1382 copy-1 is 11.206659
# Euclidean distance from 234228 is 12.364338
# Euclidean distance from AkshayaPatil is 12.38749
# Euclidean distance from Bharmal is 12.402461
# Euclidean distance from IMG_20190702_225053_ed_SMALL SIZE is 12.295832
# Euclidean distance from Deepak Moonat is 12.265258
# Euclidean distance from praful-high-1553525634456 is 12.107897
# Euclidean distance from New Doc 2018-10-10 12.30.31 is 12.24502
# Euclidean distance from Nilesh Sonawane is 12.5788145
# Euclidean distance from Shubham Rajput is 9.212602
# Euclidean distance from 112455 is 12.828672
# Euclidean distance from Photo (White Background) is 11.834806
# Euclidean distance from White Background is 12.306793
# Euclidean distance from New Doc 2019-06-04 12.42.03[11] is 11.55659
# Euclidean distance from Toral Divecha_1 is 12.395228
# Euclidean distance from SakshiNatani is 11.286861
# Euclidean distance from New Doc 2018-10-01 18.22.44(1) is 11.015143
# Euclidean distance from IMG-20190425-WA0010 is 12.130368
# Euclidean distance from Saloni Rokde is 11.095688
# Euclidean distance from 1 is 11.710474
# Euclidean distance from Twisha Saraiya is 9.630717
# Euclidean distance from 114054 is 11.676374
# Euclidean distance from JaskaranSingh is 11.416607
# Euclidean distance from passportImg is 13.612767
# Euclidean distance from Sunil Arya is 12.584227
# Euclidean distance from 13BEE0263 is 12.316931
# Euclidean distance from scan nithya photo is 12.825647
# Euclidean distance from 184737-02(1) is 11.80815
# Euclidean distance from WhatsApp Image 2019-05-28 at 12.43.31 is 12.922628
# Euclidean distance from DSC_0256 is 11.323667
# Euclidean distance from IMG_RAYOMAND Y ENGINEER is 12.102646
# Euclidean distance from IMG_20190705_103352-min is 11.947659
# Euclidean distance from Arijit Majumder is 11.7375
# Euclidean distance from New Doc 2018-10-10 12.30.31(3) is 12.24502
# Euclidean distance from New Doc 2018-10-01 18.22.44(3) is 11.015143
# Euclidean distance from IMG-20190822-WA0008 is 11.193974
# Euclidean distance from Yamini Photograph is 12.543412
# Euclidean distance from Sachin Nath Deora is 11.55922
# Euclidean distance from Akshat Jain Bangalore is 11.258741
# Euclidean distance from IMG-4115 is 11.841951
# Euclidean distance from 105844 is 10.937588
# Euclidean distance from 193942 is 11.815854
# Euclidean distance from cropped image is 10.404296
# Euclidean distance from Devanshi is 11.628634
# Euclidean distance from 115134 is 12.267407
# Euclidean distance from New Doc 2018-10-01 18.22.44 (5) is 11.015143
# Euclidean distance from img is 10.949862
# Euclidean distance from 3 is 12.791537
# Euclidean distance from Varun is 10.721868
# Euclidean distance from IMG_20190702_145649 is 11.602068
# Euclidean distance from IMG_20190522_172847__01 is 12.490379
# Euclidean distance from New Doc 2019-06-10 12.17.47 is 12.028193
# Euclidean distance from Fz is 11.412983
# Euclidean distance from Arthi Kailash is 12.215087
# Euclidean distance from K Prashanth Kumar (Bangalore) is 11.849462
# Euclidean distance from photograph is 12.586637
# Euclidean distance from file-4 is 11.813939
# Euclidean distance from Malavika5 is 12.190247
# Euclidean distance from Joshua_Almeida_Picture_BA is 10.67209
# Euclidean distance from SHubham is 11.660834
# Euclidean distance from 230609 is 11.276737
# Euclidean distance from Akanksha Vora is 12.47897
# Euclidean distance from New Doc 2019-04-02 16.56.29 is 11.3907175
# Euclidean distance from PrashantSaive is 11.9400625
# Euclidean distance from Debasmita Dasgupta is 12.37852
# Euclidean distance from 174116[1] is 13.388307
# Euclidean distance from Mohsin Khan (Bangalore) is 12.120552
# Euclidean distance from Swapnil Bera Bangalore is 11.199486
# Euclidean distance from photo-1555912899664 is 11.842973
# Euclidean distance from Divyesh Bohra is 12.109231
# Euclidean distance from WhatsApp Image 2019-05-28 at 11.03.50 AM is 11.847892
# Euclidean distance from pallavi_kadam is 13.483173
# Euclidean distance from sandesh is 11.186478
# Euclidean distance from sumit-parasmal-jain-bro-vasai-5 is 11.263899
# Euclidean distance from 20190702_182629 is 10.136
# Euclidean distance from WhatsApp Image 2019-05-29 at 5.19.07 PM is 11.212255
# Euclidean distance from Anubhav Kar is 10.807321
# Euclidean distance from Vaibhav Agarwal - Q0614 is 11.993553
# Euclidean distance from 175127 is 11.695764
# Euclidean distance from krutik_menkudle is 11.42392
# Euclidean distance from New Doc 2018-10-01 18.22.44 (2) is 11.015143
# Euclidean distance from 1 (3) is 12.431708
# Euclidean distance from PHOTO-2019-07-24-19-08-20 is 12.134198
# Euclidean distance from vinit is 11.483386
# Euclidean distance from Divya Dinesh Thottiparambil is 12.155181
# Euclidean distance from IMG_20190729_165945__01 is 13.388925
# Euclidean distance from 0164ab is 12.380345
# Euclidean distance from IMG20190702215815 is 10.9466
# Euclidean distance from SPIT is 11.186872
# Euclidean distance from Akshat Shetty is 11.452183
# Euclidean distance from YashrajGangalPhotograph is 10.579927
# Euclidean distance from 184901 is 12.910023
# Euclidean distance from Abhinav Thakur is 11.671755
# Euclidean distance from New Doc 2019-04-16 10.55.36 is 11.380852
# Euclidean distance from Kumar is 11.367642
# Euclidean distance from DSC0045 is 12.42356
# Euclidean distance from FB_IMG_1561369648764 is 11.714762
# Euclidean distance from ANKESH PATIL is 11.5767765
# Euclidean distance from 182801 is 13.202034
# Euclidean distance from Gaurav Vashishtha - Bangalore is 12.062911
# Euclidean distance from Katta Abhishek Bangalore is 11.213825
# Euclidean distance from mj is 11.6129
# Euclidean distance from NMIMS is 11.460642
# Euclidean distance from Manjunath Bangalore is 11.609508
# Euclidean distance from HDR is 11.613809
# Euclidean distance from Asmiriti_Kumari_Photograph_AIT_Pune is 12.260941
# Euclidean distance from IMG_20190429_130317_030 is 13.282228
# Euclidean distance from IMG-20190702-WA0005 is 12.37748
# Euclidean distance from saurabh roy is 11.670979
# Euclidean distance from Gupta(Bangalore) is 11.241871
# Euclidean distance from IMG_20190702_182330 is 11.828662
# Euclidean distance from 80 is 10.5573635
# Euclidean distance from 943 is 11.960895
# Euclidean distance from New Doc 2018-10-10 12.30.31 (9) is 12.24502
# Euclidean distance from Himani is 12.330489
# Euclidean distance from rahulkumarsinghbangalore is 11.492647
# Euclidean distance from PHOTO is 12.48149
# Euclidean distance from AsthaJain is 12.223433
# Euclidean distance from IMG_20181114_185939__01 is 12.773173
# Euclidean distance from scan_pic is 11.069564
# Euclidean distance from Apurv Gupta is 11.963886
# Euclidean distance from Prakash ID photo is 11.569605
# Euclidean distance from 8-Saurabh-1x1 is 11.034638
# Euclidean distance from 2018-09-17-09-14-29 is 11.326409
# Euclidean distance from Avinash Sidhwani is 12.341718
# Euclidean distance from mypic is 11.787382
# Euclidean distance from Abd is 11.321351
# Euclidean distance from LEKHANA is 11.269301
# Euclidean distance from 118-AVINAV is 12.231538
# Euclidean distance from IMG_20180321_221006 (1) is 11.897327
# Euclidean distance from Vaibhav is 11.985178
# Euclidean distance from New Doc 2018-10-10 12.30.31(2) is 12.24502
# Euclidean distance from Abhishek Jha is 11.746708
# Euclidean distance from Official is 12.008247
# Euclidean distance from Arun Chandhar Ravi (Bangalore) is 11.685849
# Euclidean distance from Screenshot_20190805-193339__01 is 13.442736
# Euclidean distance from n is 11.077795
# Euclidean distance from cfad876a-7482-4a7b-981d-6b6f1a765e4a is 11.886445
# Euclidean distance from Photograph passport size is 11.821879
# Euclidean distance from New Doc 2018-10-10 12.30.31(1) is 12.24502
# Euclidean distance from PHOTO-2019-07-04-22-02-30 is 13.314921
# Euclidean distance from 16004 is 12.310235
# Euclidean distance from Screenshot_20190723-085220__01 is 12.945629
# Euclidean distance from SrashtiDhakad is 12.687889
# Euclidean distance from photo-1557862443929 is 11.857763
# Euclidean distance from Shubham Mukherjee is 11.744353
# Euclidean distance from Parag Sharma is 11.30844
# Euclidean distance from krutika is 12.408614
# Euclidean distance from Sriharsha B S Prasad Bangalore is 11.590153
# Euclidean distance from PassportSize-29.05.2019 is 11.754226
# Euclidean distance from FB_IMG_1550894132150 is 12.2177925
# Euclidean distance from 2 is 11.736355
# Euclidean distance from MelburneRodrigues is 11.411936
# Euclidean distance from Yash_Mehta_whitebackground is 10.914179
# Euclidean distance from 182020 is 12.045381
# Euclidean distance from n (1) is 12.019856
# Euclidean distance from 8558 is 11.606496
# Euclidean distance from Vivek Photo is 11.60323
# Euclidean distance from 102731719 is 12.7127695
# Euclidean distance from 08 - photograph is 12.401043
# Euclidean distance from New Doc 2018-10-01 18.22.44 is 11.015143
# Euclidean distance from New Doc 2018-10-01 18.22.44(4) is 11.015143
# Euclidean distance from 104607 is 11.327155
# Euclidean distance from WhatsApp Image 2019-06-04 at 12.55.15 PM is 11.961879
# Euclidean distance from PassportSize is 11.575904
# Euclidean distance from Kanchan Rawat is 12.241849
# Euclidean distance from prem is 11.691771
# Euclidean distance from 1a is 11.724068
# Euclidean distance from 1.1 is 11.362999
# Euclidean distance from aishwarya(Bangalore) is 12.675454
# Euclidean distance from sanyogita is 11.384815
# Euclidean distance from Ajad is 11.763999
# Euclidean distance from Ritesh Joseph is 12.205876
# Euclidean distance from Pawar is 11.917586
# Euclidean distance from Pic is 11.59586
# Euclidean distance from PassportSize  is 11.278433
# Euclidean distance from Ayush is 11.630013
# Euclidean distance from A4 size pic is 13.388495
# Euclidean distance from Sarath kumar Tamminana is 10.492425
# Euclidean distance from passportsize-1547968705966 is 11.633128
# Euclidean distance from 000015-01 is 12.814034
# Euclidean distance from 095142 is 12.198667
# Euclidean distance from Quantiphi photo is 13.467417
# Euclidean distance from patil is 12.287093
# Euclidean distance from 1-1 is 11.89062
# Euclidean distance from Rishi is 10.870686
# Euclidean distance from New Doc 2018-10-01 18.22.44 (9) is 11.015143
# Euclidean distance from Photo 1 is 12.508016
# Euclidean distance from Tanmay_Parulekar is 11.554108
# Euclidean distance from 4 is 11.206809
# Euclidean distance from preview 1 is 11.597577
# Euclidean distance from New Doc 2018-10-10 12.30.31(4) is 12.24502
# Euclidean distance from PicsArt_06-15-12.55.51 is 11.278036
# Euclidean distance from 17469 is 12.062167
# Euclidean distance from 7497 is 11.258935
# Euclidean distance from pradeep is 11.489483
# Euclidean distance from 21 is 12.146816
# Euclidean distance from Mrutyunjay Hiremath is 11.812664
# Euclidean distance from 194533 is 11.727469
# Euclidean distance from Sohail Anwar- Bangalore is 11.40821
# Euclidean distance from IMG-5871 is 12.424665
# Euclidean distance from Shivani is 13.050613
# Euclidean distance from scan0044 is 10.812265
# Euclidean distance from 141456B4-CB2D-464A-AB0A-094B980DC0E3 is 12.094391
# Euclidean distance from Piyush Profile Pic is 11.115094
# Euclidean distance from New Doc 2018-10-01 18.22.44 (7) is 11.015143
# Euclidean distance from 807 is 12.605377
# Euclidean distance from Maitri_Fafadia_PhotoGraph_DJSCE is 11.060089
# Euclidean distance from New Doc 2018-10-10 12.30.31 (8) is 12.24502
# Euclidean distance from 16 is 11.319829
# Euclidean distance from Felicia Photograph is 13.513175
# Euclidean distance from IMG is 11.415915
# Euclidean distance from ritvik joshi is 11.891504
# Euclidean distance from New Doc 2018-10-01 18.22.44 (4) is 11.015143
# Euclidean distance from Aradhana_Pandey_Photograph_VNIT_Nagpur is 12.662362
# Euclidean distance from mohit bhalodia is 11.306698
# Euclidean distance from Austin Dsouza is 11.670737
# Euclidean distance from Sathish Krishnan (Bangalore) is 11.797594
# Euclidean distance from quantiphi is 11.616075
# Euclidean distance from Musaveer A Holalkere Bangalore is 12.123947
# Euclidean distance from jash_shah_DE is 11.573975
# Euclidean distance from IMG20190601132155 is 11.941725
# Euclidean distance from Ameet Choudhary is 11.702854
# Euclidean distance from Millennium Bismay (Bangalore) is 10.843104
# Euclidean distance from 6920 copy is 11.558359
# Euclidean distance from unnamed is 11.556982
# Euclidean distance from white is 11.788473
# Euclidean distance from Brahmankar(Sinkar) is 10.857593
# Euclidean distance from Amit Kumar Ram is 12.719818
# Euclidean distance from Ankita_Vaidya is 11.587368
# Euclidean distance from ashish_pic is 11.896424
# Euclidean distance from Rahul Kandari - 1288 is 12.078542
# Euclidean distance from passport photo is 12.277132
# Euclidean distance from FullSizeRender-min is 11.736583
# Euclidean distance from Shivam.Singh is 11.496874
# Euclidean distance from karthik shathiri (bengaluru) is 11.981434
# Euclidean distance from Vishal Waghmare is 11.903705
# Euclidean distance from Anand Santosh Jha is 13.017546
# Euclidean distance from Balapanuru is 11.791478
# Euclidean distance from HARSHITA is 12.14439
# Euclidean distance from IMG-20190729-WA0010 is 12.558457
# Euclidean distance from PASSPORT SIZE PHOTO is 12.008221
# Euclidean distance from 185655 is 11.526017
# Euclidean distance from Pic with White BG is 11.166541
# Euclidean distance from SushanthD_Bangalore is 11.327012
# Euclidean distance from 32 AM Office Lens is 12.7652235
# Euclidean distance from jogdand is 11.6129
# Euclidean distance from 399 is 12.82473
# Euclidean distance from V Subbaiah Bangalore is 12.214926
# Euclidean distance from DSC_0145 is 11.09544
# Euclidean distance from Mustufahasan Shabbir Surti is 13.8319235
# Euclidean distance from Shobha is 11.994546
# Euclidean distance from 15040-115 is 11.33278
# Euclidean distance from IMG-20190507-WA0002 is 12.510477
# Euclidean distance from risheekesh is 12.461544
# Euclidean distance from New Doc 2018-10-10 12.30.31 (2) is 12.24502
# Euclidean distance from Disha_Shetty_Photo_PCCOE is 11.763425
# Euclidean distance from PP is 10.845068
# Euclidean distance from PhotoGrid_1562071481388 is 11.7291565
# Euclidean distance from Ketan S Palankar Bangalore is 11.52958
# Euclidean distance from whiteback is 11.138319
# Euclidean distance from WhatsApp Image 2019-06-08 at 17.52.25 is 11.784199
# Euclidean distance from IMG_20190703_105824 is 12.248419
# Euclidean distance from 0007 - Copy is 12.263483
# Euclidean distance from Parvati is 10.818429
# Euclidean distance from Sai Appala Raju I (Banglore) is 10.920929
# Euclidean distance from kavish mehta(Bangalore) is 11.691669
# Euclidean distance from pereira is 12.699101
# Euclidean distance from Akash is 11.380852
# Euclidean distance from Photo ID white BG is 13.001403
# Euclidean distance from cat-baby-khushboo-sahu is 10.925033
# Euclidean distance from WhatsApp Image 2019-08-28 at 10.53.50 AM is 11.986947
# Euclidean distance from IIFT is 10.948903
# Euclidean distance from 161615 is 10.937229
# Euclidean distance from 111717 is 11.8467455
# Euclidean distance from Ketav is 11.609362
# Euclidean distance from Gaurav Maniyar is 11.9394865
# Euclidean distance from ipg_2014074 is 11.44397
# Euclidean distance from bangalore is 11.609314
# Euclidean distance from New Doc 2018-10-10 12.30.31 (3) is 12.24502
# Euclidean distance from Gail Cardozo is 11.968045
# Euclidean distance from 103518 is 11.318884
# Euclidean distance from New Doc 2019-07-03 12.15.08 is 12.750799
# Euclidean distance from Vasant_Mahadik_Passport Size Photo is 12.143443
# Euclidean distance from Hitesh(Bangalore) is 12.145621
# Euclidean distance from Vasu(Bangalore) is 12.788879
# Euclidean distance from 182940 is 12.098584
# Euclidean distance from IMG_20190716_150042 is 12.090259
# Euclidean distance from Passport Photo (2019.03.31) - Rijul Raut is 11.785083
# Euclidean distance from card is 11.549049
# Euclidean distance from 200101 is 10.371972
# Euclidean distance from IMG_20190702_225008__01 is 10.813913
# Euclidean distance from Krunal photo-1 is 12.475121
# Euclidean distance from img048 is 11.873283
# Euclidean distance from 869 is 11.420583
# Euclidean distance from Mishall_Swain is 11.521234
# Euclidean distance from Suraj_Bangalore is 11.796371
# Euclidean distance from Rituparna adha_bengaluru is 11.989497
# Euclidean distance from arvind is 10.962576
# Euclidean distance from Ashutosh Patidar is 11.958445
# Euclidean distance from New Doc 2018-10-10 12.30.31 (7) is 12.24502
# Euclidean distance from linked is 12.458663
# Euclidean distance from 7462 is 12.1074295
# Euclidean distance from Patil_Siddhant_Vitthal is 11.653529
# Euclidean distance from 154936 is 11.89874
# Euclidean distance from Arjun picv is 12.223783
# Euclidean distance from Bharat is 12.316766
# Euclidean distance from Ankit Goyal is 11.551839
# Euclidean distance from Solanki is 11.302005
# Euclidean distance from Subhankar Pati(Bangalore) is 11.318884
# Euclidean distance from Abhijeet.Tarale Bangalore is 11.251857
# Euclidean distance from 101436 is 10.967593
# Euclidean distance from Yaramala.Spandana(Bangalore) is 11.750007
# Euclidean distance from IMG-20190530-WA0009 is 11.602111
# Euclidean distance from Osheen is 12.503868
# Euclidean distance from New Doc 2018-10-10 12.30.31 (6) is 12.24502
# Euclidean distance from Kamal is 12.156003
# Euclidean distance from ArchID is 12.1248865
# Euclidean distance from New Doc 2018-10-01 18.22.44 (8) is 11.015143
# Euclidean distance from Image  is 12.146566
# Euclidean distance from Pooja Sharma is 12.148663
# Euclidean distance from Vijay Mannur is 11.267131
# Euclidean distance from MANGALEKAR is 11.129147
# Euclidean distance from AkankshaJoshi is 11.604166
# Euclidean distance from engineering-1547745743836 is 10.934363
# Euclidean distance from 2018-09-05-20-55-01-852 is 12.547714
# Euclidean distance from Neelesh Yadav Bangalore is 11.451069
# Euclidean distance from NidhiJain(Banglore) is 12.419569
# Euclidean distance from photo-1553354936430 is 10.908437
# Euclidean distance from varghese is 12.730815
# Euclidean distance from formal pic is 10.637495
# Euclidean distance from Nazmeen copy is 11.1495
# Euclidean distance from 00 is 12.231233
# Euclidean distance from 7619 is 12.1129875
# Euclidean distance from AqibImage - Copy is 12.149021
# Euclidean distance from prakshal is 12.154826
# Euclidean distance from Photograph is 11.302247
# Euclidean distance from KabirSachdevImage is 11.956119
# Euclidean distance from 59.152.53.203(optimized) is 12.692682
# Euclidean distance from shrutichoudhari is 10.520298
# Euclidean distance from 20190816_082257 is 11.839883
# Euclidean distance from 7008 is 11.628687
# Euclidean distance from ramkumar is 12.020238
# Euclidean distance from swaroop is 11.433068
# Euclidean distance from passport size photo - Mudita Sisodia is 12.176668
# Euclidean distance from 20190703_154159 is 11.396537
# Euclidean distance from karan photo is 12.070232
# Euclidean distance from Shashwath is 12.1644335
# Euclidean distance from Vridhi Shah is 12.564068
# Euclidean distance from Divya Pascal (Bangalore) is 11.5873575
# Euclidean distance from picture is 12.536019
# Euclidean distance from Shekhar Bhalsing is 11.059104
# Euclidean distance from AravindMenon(Bangalore) is 11.807044
# Euclidean distance from Karukonda_Nikhil_Reddy(Bangalore) is 11.775909
# Euclidean distance from Passport Pic is 13.2147875
# Euclidean distance from IMG-20161121-WA0046 is 11.793004
# Euclidean distance from o is 11.872095
# Euclidean distance from Mokshadayini Narsule is 12.634213
# Euclidean distance from Shubhada-Padwal-Passport-Photo-1 is 12.504108
# Euclidean distance from Bhavesh is 11.700263
# Euclidean distance from 9809e056-4973-4a95-a2ea-7f6909afaf7b is 12.503868
# Euclidean distance from New Doc 2018-10-01 18.22.44 (6) is 11.015143
# Euclidean distance from AyushBahuguna(Bangalore) is 10.069189
# Euclidean distance from Amit_Deshwal_SD is 11.469795
# Euclidean distance from DSC0051 copy 2 is 12.351056
# Euclidean distance from New Doc 2019-05-29 10.40.02 is 11.982773
# Euclidean distance from 1.PHOTO is 11.796999
# Euclidean distance from Photo-1 is 11.784782
# Euclidean distance from AkshayWagh is 10.257498
# Euclidean distance from download is 12.210752
# Euclidean distance from New Doc 2018-10-01 18.22.44 (1) is 11.015143
# Euclidean distance from New Doc 2018-09-30 21.25.49 is 11.677413
# Euclidean distance from KaustubhMaheshKhavnekar is 12.559109
# Euclidean distance from photo-1 is 12.507156
# Euclidean distance from 115429 is 10.681535
# Euclidean distance from IMG_20171029_143708_01_01_01 is 12.318023
# Euclidean distance from viewer is 13.113832
# Euclidean distance from 165154-min is 11.5891075
# Euclidean distance from Tejas_20Ved is 12.162159
# Euclidean distance from Palash is 11.771119
# Euclidean distance from 234041 is 11.944221
# Euclidean distance from 8thsep is 11.645285
# Euclidean distance from Sumi Neogi is 12.039127
# Euclidean distance from Khyati_20Parashar is 13.49834
# Euclidean distance from Abhishek Patra, Bangalore is 11.169969
# Time Taken :  0.06642842292785645
# Euclidean distance from Nikhil is 11.248644
# Euclidean distance from viewPhoto is 11.646731
# Euclidean distance from image_resize is 11.767913
# Euclidean distance from resize is 12.253129
# Euclidean distance from Photo is 13.794514
# Euclidean distance from 081744 is 12.267993
# Euclidean distance from AJAY KUMAR GOND is 11.846335
# Euclidean distance from 0055 is 12.542914
# Euclidean distance from Manideepa_Pabbathineni(Bangalore) is 10.989483
# Euclidean distance from size is 11.988393
# Euclidean distance from gautham is 11.9929
# Euclidean distance from 200 is 10.392691
# Euclidean distance from kristen is 10.911672
# Euclidean distance from DSC_6418 (2) is 11.462547
# Euclidean distance from Image is 12.28852
# Euclidean distance from Bengaluru is 11.904446
# Euclidean distance from IMG-20190610-WA0006 is 10.668805
# Euclidean distance from Formal Photo is 11.924053
# Euclidean distance from KAMAKSHI ANANTHARAMAN  is 12.526926
# Euclidean distance from IMG_20190715_191550 is 13.291929
# Euclidean distance from IMG-20190703-WA0000 is 11.092338
# Euclidean distance from Jibin Philip Raju is 12.745158
# Euclidean distance from 2253 is 11.643126
# Euclidean distance from New Doc 2019-07-02 18.23.34_1 is 11.189134
# Euclidean distance from New Doc 2018-10-10 12.30.31 (5) is 12.309062
# Euclidean distance from id card is 11.6105385
# Euclidean distance from 1558980574259 is 12.578879
# Euclidean distance from 02 is 11.343231
# Euclidean distance from Anubhav Tiwari (Bangalore) is 10.074966
# Euclidean distance from zz1 is 9.789636
# Euclidean distance from Nikita Nair 1 is 13.615677
# Euclidean distance from 1.2 is 12.093355
# Euclidean distance from Basmatkar is 11.623039
# Euclidean distance from 0412 is 11.624798
# Euclidean distance from 131126 is 11.883429
# Euclidean distance from edited is 11.74534
# Euclidean distance from nandita is 10.985705
# Euclidean distance from amritabasurbi is 12.605018
# Euclidean distance from 01 is 11.744683
# Euclidean distance from jeevan is 12.548924
# Euclidean distance from Asmita is 12.323048
# Euclidean distance from IMG_8040 is 11.135099
# Euclidean distance from 1-1558779272408 is 11.898163
# Euclidean distance from ankita is 12.525289
# Euclidean distance from photo is 11.3201885
# Euclidean distance from Bangalore is 12.333347
# Euclidean distance from Photo ID is 12.842786
# Euclidean distance from Shitij is 11.434309
# Euclidean distance from 20190723_130020 is 13.518715
# Euclidean distance from New Doc 2018-10-10 12.30.31 (4) is 12.309062
# Euclidean distance from New Doc 2019-07-02 18.26.28 is 9.976946
# Euclidean distance from IMG-20190602-WA0002 is 11.650822
# Euclidean distance from kishan is 12.848516
# Euclidean distance from bhalerao is 12.480906
# Euclidean distance from Anish Pandita is 12.621129
# Euclidean distance from Jefrin is 11.756058
# Euclidean distance from IMG-20190805-WA0022 is 11.167368
# Euclidean distance from sachin is 11.011006
# Euclidean distance from Debrup_20Photo_20Scan is 11.56195
# Euclidean distance from Suvan is 10.897734
# Euclidean distance from new doc 2019-07-03 15.29.27_1 is 11.611451
# Euclidean distance from Photo from Mayank Bhardwaj is 12.4967375
# Euclidean distance from IMG_0874 is 11.078664
# Euclidean distance from ID is 11.368037
# Euclidean distance from Alka is 11.792179
# Euclidean distance from 091556 is 13.385928
# Euclidean distance from Amit-passport is 11.214811
# Euclidean distance from vishakha is 12.429285
# Euclidean distance from KarishmaZambare is 11.670321
# Euclidean distance from New Doc 2018-10-10 12.30.31 (1) is 12.309062
# Euclidean distance from AdvaitAnilSarang is 11.536827
# Euclidean distance from 6832 is 11.226796
# Euclidean distance from IMG_20190729_1709329781 is 11.541872
# Euclidean distance from Anuja_photo is 11.33403
# Euclidean distance from photo-1555078942270 is 10.873729
# Euclidean distance from IMG_20190703_171118122 is 13.183581
# Euclidean distance from Nayan Dhuri is 11.894354
# Euclidean distance from pic is 11.7959175
# Euclidean distance from photograph-page-001 is 10.165494
# Euclidean distance from 0 is 11.898677
# Euclidean distance from 04 is 12.116345
# Euclidean distance from New Doc 2018-10-01 18.22.44(2) is 11.101115
# Euclidean distance from nikesh photo is 12.43821
# Euclidean distance from 190054 is 11.836833
# Euclidean distance from Passport Picture_1 is 12.504948
# Euclidean distance from Passport Size Photo is 11.640849
# Euclidean distance from INDRANIL PAUL is 10.736547
# Euclidean distance from Sneha_Biradar_Photograph is 12.2495575
# Euclidean distance from isa_photo is 11.412403
# Euclidean distance from a016 is 11.147356
# Euclidean distance from 165404 (1) is 12.736516
# Euclidean distance from New Doc 2018-10-01 18.22.44 (3) is 11.101115
# Euclidean distance from Sakshi_Subedi is 12.733769
# Euclidean distance from Indore is 12.859939
# Euclidean distance from Passport is 11.729754
# Euclidean distance from Avinash Giridhar (Bangalore) is 11.899601
# Euclidean distance from Ashay Shukla is 11.90846
# Euclidean distance from ravi is 12.171294
# Euclidean distance from Nishanth is 11.1797085
# Euclidean distance from Shubham_burned is 11.274608
# Euclidean distance from Harshesh_Sayani is 11.078045
# Euclidean distance from SUNAIN is 12.719305
# Euclidean distance from SagarSingh is 11.950886
# Euclidean distance from Neeraj Passport is 11.370284
# Euclidean distance from Pujari Sai Vamsi (Bangalore) is 11.17085
# Euclidean distance from 2018-08-09-09-02-24-009 is 12.743424
# Euclidean distance from Picture is 12.176463
# Euclidean distance from Passport Photo is 11.998265
# Euclidean distance from IMG_20190702_182417~2 is 12.354047
# Euclidean distance from ravindra Passport photo is 12.135838
# Euclidean distance from New Doc 2019-05-29 09.27.19(1) is 12.183318
# Euclidean distance from V V CHAKRADHAR (Bangalore) is 11.551726
# Euclidean distance from Rushikesh Hande is 12.595338
# Euclidean distance from 1382 copy-1 is 11.25028
# Euclidean distance from 234228 is 12.333681
# Euclidean distance from AkshayaPatil is 12.413844
# Euclidean distance from Bharmal is 12.417955
# Euclidean distance from IMG_20190702_225053_ed_SMALL SIZE is 12.364953
# Euclidean distance from Deepak Moonat is 12.262414
# Euclidean distance from praful-high-1553525634456 is 12.161954
# Euclidean distance from New Doc 2018-10-10 12.30.31 is 12.309062
# Euclidean distance from Nilesh Sonawane is 12.625261
# Euclidean distance from Shubham Rajput is 9.294032
# Euclidean distance from 112455 is 12.913147
# Euclidean distance from Photo (White Background) is 11.905026
# Euclidean distance from White Background is 12.376798
# Euclidean distance from New Doc 2019-06-04 12.42.03[11] is 11.678772
# Euclidean distance from Toral Divecha_1 is 12.469961
# Euclidean distance from SakshiNatani is 11.289748
# Euclidean distance from New Doc 2018-10-01 18.22.44(1) is 11.101115
# Euclidean distance from IMG-20190425-WA0010 is 12.17378
# Euclidean distance from Saloni Rokde is 11.181452
# Euclidean distance from 1 is 11.747319
# Euclidean distance from Twisha Saraiya is 9.675957
# Euclidean distance from 114054 is 11.74027
# Euclidean distance from JaskaranSingh is 11.428865
# Euclidean distance from passportImg is 13.628664
# Euclidean distance from Sunil Arya is 12.643496
# Euclidean distance from 13BEE0263 is 12.398306
# Euclidean distance from scan nithya photo is 12.929862
# Euclidean distance from 184737-02(1) is 11.821212
# Euclidean distance from WhatsApp Image 2019-05-28 at 12.43.31 is 12.939341
# Euclidean distance from DSC_0256 is 11.299108
# Euclidean distance from IMG_RAYOMAND Y ENGINEER is 12.092267
# Euclidean distance from IMG_20190705_103352-min is 11.969034
# Euclidean distance from Arijit Majumder is 11.761105
# Euclidean distance from New Doc 2018-10-10 12.30.31(3) is 12.309062
# Euclidean distance from New Doc 2018-10-01 18.22.44(3) is 11.101115
# Euclidean distance from IMG-20190822-WA0008 is 11.241784
# Euclidean distance from Yamini Photograph is 12.599467
# Euclidean distance from Sachin Nath Deora is 11.630646
# Euclidean distance from Akshat Jain Bangalore is 11.271109
# Euclidean distance from IMG-4115 is 11.959815
# Euclidean distance from 105844 is 10.9883795
# Euclidean distance from 193942 is 11.889954
# Euclidean distance from cropped image is 10.493539
# Euclidean distance from Devanshi is 11.681677
# Euclidean distance from 115134 is 12.328233
# Euclidean distance from New Doc 2018-10-01 18.22.44 (5) is 11.101115
# Euclidean distance from img is 10.962252
# Euclidean distance from 3 is 12.877953
# Euclidean distance from Varun is 10.726623
# Euclidean distance from IMG_20190702_145649 is 11.648566
# Euclidean distance from IMG_20190522_172847__01 is 12.5758705
# Euclidean distance from New Doc 2019-06-10 12.17.47 is 12.122582
# Euclidean distance from Fz is 11.443005
# Euclidean distance from Arthi Kailash is 12.246741
# Euclidean distance from K Prashanth Kumar (Bangalore) is 11.912231
# Euclidean distance from photograph is 12.603817
# Euclidean distance from file-4 is 11.883664
# Euclidean distance from Malavika5 is 12.188928
# Euclidean distance from Joshua_Almeida_Picture_BA is 10.734754
# Euclidean distance from SHubham is 11.701803
# Euclidean distance from 230609 is 11.287681
# Euclidean distance from Akanksha Vora is 12.557619
# Euclidean distance from New Doc 2019-04-02 16.56.29 is 11.493041
# Euclidean distance from PrashantSaive is 11.990495
# Euclidean distance from Debasmita Dasgupta is 12.383881
# Euclidean distance from 174116[1] is 13.337055
# Euclidean distance from Mohsin Khan (Bangalore) is 12.114428
# Euclidean distance from Swapnil Bera Bangalore is 11.306406
# Euclidean distance from photo-1555912899664 is 11.846951
# Euclidean distance from Divyesh Bohra is 12.062589
# Euclidean distance from WhatsApp Image 2019-05-28 at 11.03.50 AM is 11.914564
# Euclidean distance from pallavi_kadam is 13.553261
# Euclidean distance from sandesh is 11.252291
# Euclidean distance from sumit-parasmal-jain-bro-vasai-5 is 11.381779
# Euclidean distance from 20190702_182629 is 10.142604
# Euclidean distance from WhatsApp Image 2019-05-29 at 5.19.07 PM is 11.281398
# Euclidean distance from Anubhav Kar is 10.863704
# Euclidean distance from Vaibhav Agarwal - Q0614 is 12.034534
# Euclidean distance from 175127 is 11.721772
# Euclidean distance from krutik_menkudle is 11.461883
# Euclidean distance from New Doc 2018-10-01 18.22.44 (2) is 11.101115
# Euclidean distance from 1 (3) is 12.503909
# Euclidean distance from PHOTO-2019-07-24-19-08-20 is 12.164493
# Euclidean distance from vinit is 11.499886
# Euclidean distance from Divya Dinesh Thottiparambil is 12.246482
# Euclidean distance from IMG_20190729_165945__01 is 13.413578
# Euclidean distance from 0164ab is 12.342074
# Euclidean distance from IMG20190702215815 is 11.018991
# Euclidean distance from SPIT is 11.214572
# Euclidean distance from Akshat Shetty is 11.54037
# Euclidean distance from YashrajGangalPhotograph is 10.608379
# Euclidean distance from 184901 is 12.948566
# Euclidean distance from Abhinav Thakur is 11.633924
# Euclidean distance from New Doc 2019-04-16 10.55.36 is 11.434104
# Euclidean distance from Kumar is 11.391148
# Euclidean distance from DSC0045 is 12.492384
# Euclidean distance from FB_IMG_1561369648764 is 11.798769
# Euclidean distance from ANKESH PATIL is 11.604603
# Euclidean distance from 182801 is 13.277724
# Euclidean distance from Gaurav Vashishtha - Bangalore is 12.137775
# Euclidean distance from Katta Abhishek Bangalore is 11.27252
# Euclidean distance from mj is 11.709848
# Euclidean distance from NMIMS is 11.480603
# Euclidean distance from Manjunath Bangalore is 11.595869
# Euclidean distance from HDR is 11.661682
# Euclidean distance from Asmiriti_Kumari_Photograph_AIT_Pune is 12.297847
# Euclidean distance from IMG_20190429_130317_030 is 13.301356
# Euclidean distance from IMG-20190702-WA0005 is 12.440736
# Euclidean distance from saurabh roy is 11.710919
# Euclidean distance from Gupta(Bangalore) is 11.280463
# Euclidean distance from IMG_20190702_182330 is 11.879207
# Euclidean distance from 80 is 10.599163
# Euclidean distance from 943 is 12.016086
# Euclidean distance from New Doc 2018-10-10 12.30.31 (9) is 12.309062
# Euclidean distance from Himani is 12.287928
# Euclidean distance from rahulkumarsinghbangalore is 11.549203
# Euclidean distance from PHOTO is 12.528905
# Euclidean distance from AsthaJain is 12.284717
# Euclidean distance from IMG_20181114_185939__01 is 12.827306
# Euclidean distance from scan_pic is 11.157744
# Euclidean distance from Apurv Gupta is 12.035051
# Euclidean distance from Prakash ID photo is 11.680277
# Euclidean distance from 8-Saurabh-1x1 is 11.06708
# Euclidean distance from 2018-09-17-09-14-29 is 11.34587
# Euclidean distance from Avinash Sidhwani is 12.302591
# Euclidean distance from mypic is 11.851878
# Euclidean distance from Abd is 11.434658
# Euclidean distance from LEKHANA is 11.32483
# Euclidean distance from 118-AVINAV is 12.276506
# Euclidean distance from IMG_20180321_221006 (1) is 11.948308
# Euclidean distance from Vaibhav is 12.007434
# Euclidean distance from New Doc 2018-10-10 12.30.31(2) is 12.309062
# Euclidean distance from Abhishek Jha is 11.764716
# Euclidean distance from Official is 12.060639
# Euclidean distance from Arun Chandhar Ravi (Bangalore) is 11.753344
# Euclidean distance from Screenshot_20190805-193339__01 is 13.489786
# Euclidean distance from n is 11.17561
# Euclidean distance from cfad876a-7482-4a7b-981d-6b6f1a765e4a is 11.883069
# Euclidean distance from Photograph passport size is 11.829852
# Euclidean distance from New Doc 2018-10-10 12.30.31(1) is 12.309062
# Euclidean distance from PHOTO-2019-07-04-22-02-30 is 13.284488
# Euclidean distance from 16004 is 12.363744
# Euclidean distance from Screenshot_20190723-085220__01 is 13.033144
# Euclidean distance from SrashtiDhakad is 12.676142
# Euclidean distance from photo-1557862443929 is 11.88704
# Euclidean distance from Shubham Mukherjee is 11.761196
# Euclidean distance from Parag Sharma is 11.335565
# Euclidean distance from krutika is 12.448635
# Euclidean distance from Sriharsha B S Prasad Bangalore is 11.601257
# Euclidean distance from PassportSize-29.05.2019 is 11.758191
# Euclidean distance from FB_IMG_1550894132150 is 12.25393
# Euclidean distance from 2 is 11.793931
# Euclidean distance from MelburneRodrigues is 11.378753
# Euclidean distance from Yash_Mehta_whitebackground is 11.011328
# Euclidean distance from 182020 is 12.168286
# Euclidean distance from n (1) is 12.03579
# Euclidean distance from 8558 is 11.697212
# Euclidean distance from Vivek Photo is 11.6294
# Euclidean distance from 102731719 is 12.809573
# Euclidean distance from 08 - photograph is 12.442039
# Euclidean distance from New Doc 2018-10-01 18.22.44 is 11.101115
# Euclidean distance from New Doc 2018-10-01 18.22.44(4) is 11.101115
# Euclidean distance from 104607 is 11.388625
# Euclidean distance from WhatsApp Image 2019-06-04 at 12.55.15 PM is 11.98242
# Euclidean distance from PassportSize is 11.68771
# Euclidean distance from Kanchan Rawat is 12.3170395
# Euclidean distance from prem is 11.721073
# Euclidean distance from 1a is 11.755598
# Euclidean distance from 1.1 is 11.399632
# Euclidean distance from aishwarya(Bangalore) is 12.666009
# Euclidean distance from sanyogita is 11.50483
# Euclidean distance from Ajad is 11.803952
# Euclidean distance from Ritesh Joseph is 12.255852
# Euclidean distance from Pawar is 12.009766
# Euclidean distance from Pic is 11.691904
# Euclidean distance from PassportSize  is 11.298559
# Euclidean distance from Ayush is 11.585605
# Euclidean distance from A4 size pic is 13.414255
# Euclidean distance from Sarath kumar Tamminana is 10.5625305
# Euclidean distance from passportsize-1547968705966 is 11.641443
# Euclidean distance from 000015-01 is 12.823898
# Euclidean distance from 095142 is 12.219316
# Euclidean distance from Quantiphi photo is 13.519829
# Euclidean distance from patil is 12.295103
# Euclidean distance from 1-1 is 11.897203
# Euclidean distance from Rishi is 10.872103
# Euclidean distance from New Doc 2018-10-01 18.22.44 (9) is 11.101115
# Euclidean distance from Photo 1 is 12.546702
# Euclidean distance from Tanmay_Parulekar is 11.557117
# Euclidean distance from 4 is 11.239327
# Euclidean distance from preview 1 is 11.643807
# Euclidean distance from New Doc 2018-10-10 12.30.31(4) is 12.309062
# Euclidean distance from PicsArt_06-15-12.55.51 is 11.270678
# Euclidean distance from 17469 is 12.095375
# Euclidean distance from 7497 is 11.30289
# Euclidean distance from pradeep is 11.517191
# Euclidean distance from 21 is 12.178907
# Euclidean distance from Mrutyunjay Hiremath is 11.89161
# Euclidean distance from 194533 is 11.742093
# Euclidean distance from Sohail Anwar- Bangalore is 11.441332
# Euclidean distance from IMG-5871 is 12.448517
# Euclidean distance from Shivani is 13.072997
# Euclidean distance from scan0044 is 10.896869
# Euclidean distance from 141456B4-CB2D-464A-AB0A-094B980DC0E3 is 12.154933
# Euclidean distance from Piyush Profile Pic is 11.067545
# Euclidean distance from New Doc 2018-10-01 18.22.44 (7) is 11.101115
# Euclidean distance from 807 is 12.592916
# Euclidean distance from Maitri_Fafadia_PhotoGraph_DJSCE is 11.149062
# Euclidean distance from New Doc 2018-10-10 12.30.31 (8) is 12.309062
# Euclidean distance from 16 is 11.351516
# Euclidean distance from Felicia Photograph is 13.577742
# Euclidean distance from IMG is 11.51778
# Euclidean distance from ritvik joshi is 11.867574
# Euclidean distance from New Doc 2018-10-01 18.22.44 (4) is 11.101115
# Euclidean distance from Aradhana_Pandey_Photograph_VNIT_Nagpur is 12.6569805
# Euclidean distance from mohit bhalodia is 11.35326
# Euclidean distance from Austin Dsouza is 11.735713
# Euclidean distance from Sathish Krishnan (Bangalore) is 11.859166
# Euclidean distance from quantiphi is 11.62092
# Euclidean distance from Musaveer A Holalkere Bangalore is 12.119982
# Euclidean distance from jash_shah_DE is 11.59691
# Euclidean distance from IMG20190601132155 is 11.991816
# Euclidean distance from Ameet Choudhary is 11.714279
# Euclidean distance from Millennium Bismay (Bangalore) is 10.855445
# Euclidean distance from 6920 copy is 11.676497
# Euclidean distance from unnamed is 11.598144
# Euclidean distance from white is 11.810981
# Euclidean distance from Brahmankar(Sinkar) is 10.89973
# Euclidean distance from Amit Kumar Ram is 12.715026
# Euclidean distance from Ankita_Vaidya is 11.648685
# Euclidean distance from ashish_pic is 11.941197
# Euclidean distance from Rahul Kandari - 1288 is 12.164871
# Euclidean distance from passport photo is 12.2751465
# Euclidean distance from FullSizeRender-min is 11.802462
# Euclidean distance from Shivam.Singh is 11.496067
# Euclidean distance from karthik shathiri (bengaluru) is 12.078831
# Euclidean distance from Vishal Waghmare is 11.955183
# Euclidean distance from Anand Santosh Jha is 13.0673895
# Euclidean distance from Balapanuru is 11.866218
# Euclidean distance from HARSHITA is 12.112718
# Euclidean distance from IMG-20190729-WA0010 is 12.553855
# Euclidean distance from PASSPORT SIZE PHOTO is 12.040296
# Euclidean distance from 185655 is 11.621297
# Euclidean distance from Pic with White BG is 11.243875
# Euclidean distance from SushanthD_Bangalore is 11.38848
# Euclidean distance from 32 AM Office Lens is 12.782448
# Euclidean distance from jogdand is 11.709848
# Euclidean distance from 399 is 12.919663
# Euclidean distance from V Subbaiah Bangalore is 12.205839
# Euclidean distance from DSC_0145 is 11.207574
# Euclidean distance from Mustufahasan Shabbir Surti is 13.794514
# Euclidean distance from Shobha is 12.0463295
# Euclidean distance from 15040-115 is 11.42277
# Euclidean distance from IMG-20190507-WA0002 is 12.567509
# Euclidean distance from risheekesh is 12.539884
# Euclidean distance from New Doc 2018-10-10 12.30.31 (2) is 12.309062
# Euclidean distance from Disha_Shetty_Photo_PCCOE is 11.810817
# Euclidean distance from PP is 10.877492
# Euclidean distance from PhotoGrid_1562071481388 is 11.720758
# Euclidean distance from Ketan S Palankar Bangalore is 11.5481205
# Euclidean distance from whiteback is 11.193494
# Euclidean distance from WhatsApp Image 2019-06-08 at 17.52.25 is 11.793857
# Euclidean distance from IMG_20190703_105824 is 12.257457
# Euclidean distance from 0007 - Copy is 12.270036
# Euclidean distance from Parvati is 10.875611
# Euclidean distance from Sai Appala Raju I (Banglore) is 11.000212
# Euclidean distance from kavish mehta(Bangalore) is 11.759159
# Euclidean distance from pereira is 12.753842
# Euclidean distance from Akash is 11.434104
# Euclidean distance from Photo ID white BG is 13.065773
# Euclidean distance from cat-baby-khushboo-sahu is 11.012545
# Euclidean distance from WhatsApp Image 2019-08-28 at 10.53.50 AM is 12.033351
# Euclidean distance from IIFT is 11.048846
# Euclidean distance from 161615 is 10.907532
# Euclidean distance from 111717 is 11.925444
# Euclidean distance from Ketav is 11.626697
# Euclidean distance from Gaurav Maniyar is 11.952681
# Euclidean distance from ipg_2014074 is 11.433538
# Euclidean distance from bangalore is 11.680753
# Euclidean distance from New Doc 2018-10-10 12.30.31 (3) is 12.309062
# Euclidean distance from Gail Cardozo is 12.004716
# Euclidean distance from 103518 is 11.273543
# Euclidean distance from New Doc 2019-07-03 12.15.08 is 12.726622
# Euclidean distance from Vasant_Mahadik_Passport Size Photo is 12.1965685
# Euclidean distance from Hitesh(Bangalore) is 12.095202
# Euclidean distance from Vasu(Bangalore) is 12.855064
# Euclidean distance from 182940 is 12.128379
# Euclidean distance from IMG_20190716_150042 is 12.1226845
# Euclidean distance from Passport Photo (2019.03.31) - Rijul Raut is 11.7817135
# Euclidean distance from card is 11.477669
# Euclidean distance from 200101 is 10.44836
# Euclidean distance from IMG_20190702_225008__01 is 10.893817
# Euclidean distance from Krunal photo-1 is 12.479497
# Euclidean distance from img048 is 11.792237
# Euclidean distance from 869 is 11.447262
# Euclidean distance from Mishall_Swain is 11.537838
# Euclidean distance from Suraj_Bangalore is 11.8547735
# Euclidean distance from Rituparna adha_bengaluru is 12.097725
# Euclidean distance from arvind is 10.998369
# Euclidean distance from Ashutosh Patidar is 12.01896
# ...
# Euclidean distance from Divya Dinesh Thottiparambil is 12.092907
# Euclidean distance from IMG_20190729_165945__01 is 13.61516
# Euclidean distance from 0164ab is 12.538691
# Euclidean distance from IMG20190702215815 is 11.148681
# Euclidean distance from SPIT is 11.669145
# Euclidean distance from Akshat Shetty is 12.023108
# Euclidean distance from YashrajGangalPhotograph is 10.958588
# Euclidean distance from 184901 is 12.932354
# Euclidean distance from Abhinav Thakur is 11.950924
# Euclidean distance from New Doc 2019-04-16 10.55.36 is 11.9766865
# Euclidean distance from Kumar is 11.805658
# Euclidean distance from DSC0045 is 12.063793
# Euclidean distance from FB_IMG_1561369648764 is 12.111659
# Euclidean distance from ANKESH PATIL is 11.893516
# Euclidean distance from 182801 is 13.313027
# Euclidean distance from Gaurav Vashishtha - Bangalore is 12.72055
# Euclidean distance from Katta Abhishek Bangalore is 11.561143
# Euclidean distance from mj is 11.858821
# Euclidean distance from NMIMS is 11.053465
# Euclidean distance from Manjunath Bangalore is 11.709939
# Euclidean distance from HDR is 12.148136
# Euclidean distance from Asmiriti_Kumari_Photograph_AIT_Pune is 12.388647
# Euclidean distance from IMG_20190429_130317_030 is 13.552345
# Euclidean distance from IMG-20190702-WA0005 is 12.51225
# Euclidean distance from saurabh roy is 12.042683
# Euclidean distance from Gupta(Bangalore) is 11.191791
# Euclidean distance from IMG_20190702_182330 is 12.033651
# Euclidean distance from 80 is 10.908271
# Euclidean distance from 943 is 12.328211
# Euclidean distance from New Doc 2018-10-10 12.30.31 (9) is 12.577126
# Euclidean distance from Himani is 12.450965
# Euclidean distance from rahulkumarsinghbangalore is 11.696781
# Euclidean distance from PHOTO is 12.934445
# Euclidean distance from AsthaJain is 12.474078
# Euclidean distance from IMG_20181114_185939__01 is 12.485192
# Euclidean distance from scan_pic is 11.431166
# Euclidean distance from Apurv Gupta is 12.428975
# Euclidean distance from Prakash ID photo is 12.1901245
# Euclidean distance from 8-Saurabh-1x1 is 11.6000595
# Euclidean distance from 2018-09-17-09-14-29 is 11.766763
# Euclidean distance from Avinash Sidhwani is 12.564061
# Euclidean distance from mypic is 12.609022
# Euclidean distance from Abd is 11.385639
# Euclidean distance from LEKHANA is 11.521089
# Euclidean distance from 118-AVINAV is 12.853659
# Euclidean distance from IMG_20180321_221006 (1) is 12.220607
# Euclidean distance from Vaibhav is 12.433924
# Euclidean distance from New Doc 2018-10-10 12.30.31(2) is 12.577126
# Euclidean distance from Abhishek Jha is 12.2335415
# Euclidean distance from Official is 12.507459
# Euclidean distance from Arun Chandhar Ravi (Bangalore) is 11.922721
# Euclidean distance from Screenshot_20190805-193339__01 is 13.607991
# Euclidean distance from n is 10.910811
# Euclidean distance from cfad876a-7482-4a7b-981d-6b6f1a765e4a is 12.150415
# Euclidean distance from Photograph passport size is 12.533874
# Euclidean distance from New Doc 2018-10-10 12.30.31(1) is 12.577126
# Euclidean distance from PHOTO-2019-07-04-22-02-30 is 13.26445
# Euclidean distance from 16004 is 12.440059
# Euclidean distance from Screenshot_20190723-085220__01 is 13.052124
# Euclidean distance from SrashtiDhakad is 12.734291
# Euclidean distance from photo-1557862443929 is 12.42777
# Euclidean distance from Shubham Mukherjee is 12.373417
# Euclidean distance from Parag Sharma is 11.551911
# Euclidean distance from krutika is 12.649602
# Euclidean distance from Sriharsha B S Prasad Bangalore is 12.077214
# Euclidean distance from PassportSize-29.05.2019 is 11.957989
# Euclidean distance from FB_IMG_1550894132150 is 12.0900135
# Euclidean distance from 2 is 11.920223
# Euclidean distance from MelburneRodrigues is 12.004871
# Euclidean distance from Yash_Mehta_whitebackground is 11.384322
# Euclidean distance from 182020 is 12.13149
# Euclidean distance from n (1) is 12.63851
# Euclidean distance from 8558 is 11.686364
# Euclidean distance from Vivek Photo is 11.604366
# Euclidean distance from 102731719 is 12.246036
# Euclidean distance from 08 - photograph is 12.920981
# Euclidean distance from New Doc 2018-10-01 18.22.44 is 11.447719
# Euclidean distance from New Doc 2018-10-01 18.22.44(4) is 11.447719
# Euclidean distance from 104607 is 11.798537
# Euclidean distance from WhatsApp Image 2019-06-04 at 12.55.15 PM is 12.536003
# Euclidean distance from PassportSize is 11.931277
# Euclidean distance from Kanchan Rawat is 12.628192
# Euclidean distance from prem is 11.490113
# Euclidean distance from 1a is 12.249394
# Euclidean distance from 1.1 is 11.745544
# Euclidean distance from aishwarya(Bangalore) is 12.800147
# Euclidean distance from sanyogita is 11.518381
# Euclidean distance from Ajad is 12.282642
# Euclidean distance from Ritesh Joseph is 12.530057
# Euclidean distance from Pawar is 12.408357
# Euclidean distance from Pic is 12.22205
# Euclidean distance from PassportSize  is 11.453018
# Euclidean distance from Ayush is 11.99352
# Euclidean distance from A4 size pic is 13.392595
# Euclidean distance from Sarath kumar Tamminana is 10.942237
# Euclidean distance from passportsize-1547968705966 is 11.868567
# Euclidean distance from 000015-01 is 13.319546
# Euclidean distance from 095142 is 12.632564
# Euclidean distance from Quantiphi photo is 13.845083
# Euclidean distance from patil is 12.852754
# Euclidean distance from 1-1 is 11.956968
# Euclidean distance from Rishi is 11.491337
# Euclidean distance from New Doc 2018-10-01 18.22.44 (9) is 11.447719
# Euclidean distance from Photo 1 is 13.06
# Euclidean distance from Tanmay_Parulekar is 12.192162
# Euclidean distance from 4 is 11.616901
# Euclidean distance from preview 1 is 11.813903
# Euclidean distance from New Doc 2018-10-10 12.30.31(4) is 12.577126
# Euclidean distance from PicsArt_06-15-12.55.51 is 11.234424
# Euclidean distance from 17469 is 12.345928
# Euclidean distance from 7497 is 11.901694
# Euclidean distance from pradeep is 12.220944
# Euclidean distance from 21 is 12.2560835
# Euclidean distance from Mrutyunjay Hiremath is 12.221225
# Euclidean distance from 194533 is 11.792992
# Euclidean distance from Sohail Anwar- Bangalore is 11.573591
# Euclidean distance from IMG-5871 is 12.802668
# Euclidean distance from Shivani is 13.270036
# Euclidean distance from scan0044 is 10.991451
# Euclidean distance from 141456B4-CB2D-464A-AB0A-094B980DC0E3 is 12.464347
# Euclidean distance from Piyush Profile Pic is 11.856898
# Euclidean distance from New Doc 2018-10-01 18.22.44 (7) is 11.447719
# Euclidean distance from 807 is 13.173843
# Euclidean distance from Maitri_Fafadia_PhotoGraph_DJSCE is 11.33434
# Euclidean distance from New Doc 2018-10-10 12.30.31 (8) is 12.577126
# Euclidean distance from 16 is 11.3733425
# Euclidean distance from Felicia Photograph is 13.771615
# Euclidean distance from IMG is 11.475268
# Euclidean distance from ritvik joshi is 12.670669
# Euclidean distance from New Doc 2018-10-01 18.22.44 (4) is 11.447719
# Euclidean distance from Aradhana_Pandey_Photograph_VNIT_Nagpur is 13.223403
# Euclidean distance from mohit bhalodia is 11.615664
# Euclidean distance from Austin Dsouza is 12.175791
# Euclidean distance from Sathish Krishnan (Bangalore) is 11.836286
# Euclidean distance from quantiphi is 11.912475
# Euclidean distance from Musaveer A Holalkere Bangalore is 12.412665
# Euclidean distance from jash_shah_DE is 11.786334
# Euclidean distance from IMG20190601132155 is 12.152813
# Euclidean distance from Ameet Choudhary is 12.145491
# Euclidean distance from Millennium Bismay (Bangalore) is 10.932432
# Euclidean distance from 6920 copy is 11.691458
# Euclidean distance from unnamed is 11.49746
# Euclidean distance from white is 12.251383
# Euclidean distance from Brahmankar(Sinkar) is 11.04141
# Euclidean distance from Amit Kumar Ram is 13.098352
# Euclidean distance from Ankita_Vaidya is 11.5403385
# Euclidean distance from ashish_pic is 12.4125
# Euclidean distance from Rahul Kandari - 1288 is 12.446345
# Euclidean distance from passport photo is 12.2888775
# Euclidean distance from FullSizeRender-min is 12.157132
# Euclidean distance from Shivam.Singh is 12.299155
# Euclidean distance from karthik shathiri (bengaluru) is 12.02725
# Euclidean distance from Vishal Waghmare is 12.285831
# Euclidean distance from Anand Santosh Jha is 13.28915
# Euclidean distance from Balapanuru is 12.136506
# Euclidean distance from HARSHITA is 11.939447
# Euclidean distance from IMG-20190729-WA0010 is 13.170173
# Euclidean distance from PASSPORT SIZE PHOTO is 12.5969
# Euclidean distance from 185655 is 11.38838
# Euclidean distance from Pic with White BG is 11.464695
# Euclidean distance from SushanthD_Bangalore is 11.534611
# Euclidean distance from 32 AM Office Lens is 12.939282
# Euclidean distance from jogdand is 11.858821
# Euclidean distance from 399 is 13.030691
# Euclidean distance from V Subbaiah Bangalore is 12.929698
# Euclidean distance from DSC_0145 is 11.188511
# Euclidean distance from Mustufahasan Shabbir Surti is 14.371148
# Euclidean distance from Shobha is 12.34948
# Euclidean distance from 15040-115 is 12.070512
# Euclidean distance from IMG-20190507-WA0002 is 12.795919
# Euclidean distance from risheekesh is 12.792484
# Euclidean distance from New Doc 2018-10-10 12.30.31 (2) is 12.577126
# Euclidean distance from Disha_Shetty_Photo_PCCOE is 12.333245
# Euclidean distance from PP is 11.383556
# Euclidean distance from PhotoGrid_1562071481388 is 11.9343195
# Euclidean distance from Ketan S Palankar Bangalore is 11.926876
# Euclidean distance from whiteback is 11.169293
# Euclidean distance from WhatsApp Image 2019-06-08 at 17.52.25 is 12.001489
# Euclidean distance from IMG_20190703_105824 is 12.471548
# Euclidean distance from 0007 - Copy is 12.68086
# Euclidean distance from Parvati is 10.975675
# Euclidean distance from Sai Appala Raju I (Banglore) is 11.486999
# Euclidean distance from kavish mehta(Bangalore) is 11.761145
# Euclidean distance from pereira is 13.145403
# Euclidean distance from Akash is 11.9766865
# Euclidean distance from Photo ID white BG is 13.208627
# Euclidean distance from cat-baby-khushboo-sahu is 11.291978
# Euclidean distance from WhatsApp Image 2019-08-28 at 10.53.50 AM is 11.907274
# Euclidean distance from IIFT is 11.163668
# Euclidean distance from 161615 is 11.341086
# Euclidean distance from 111717 is 12.500689
# Euclidean distance from Ketav is 11.947355
# Euclidean distance from Gaurav Maniyar is 12.521706
# Euclidean distance from ipg_2014074 is 11.892357
# Euclidean distance from bangalore is 12.018302
# Euclidean distance from New Doc 2018-10-10 12.30.31 (3) is 12.577126
# Euclidean distance from Gail Cardozo is 12.342737
# Euclidean distance from 103518 is 11.983671
# Euclidean distance from New Doc 2019-07-03 12.15.08 is 12.609318
# Euclidean distance from Vasant_Mahadik_Passport Size Photo is 12.57159
# Euclidean distance from Hitesh(Bangalore) is 12.804206
# Euclidean distance from Vasu(Bangalore) is 12.4023
# Euclidean distance from 182940 is 12.529205
# Euclidean distance from IMG_20190716_150042 is 12.668148
# Euclidean distance from Passport Photo (2019.03.31) - Rijul Raut is 12.430685
# Euclidean distance from card is 12.479202
# Euclidean distance from 200101 is 10.649454
# Euclidean distance from IMG_20190702_225008__01 is 10.659315
# Euclidean distance from Krunal photo-1 is 12.694063
# Euclidean distance from img048 is 12.3655615
# Euclidean distance from 869 is 11.834105
# Euclidean distance from Mishall_Swain is 12.047182
# Euclidean distance from Suraj_Bangalore is 12.055761
# Euclidean distance from Rituparna adha_bengaluru is 12.128955
# Euclidean distance from arvind is 11.4762535
# Euclidean distance from Ashutosh Patidar is 12.396204
# Euclidean distance from New Doc 2018-10-10 12.30.31 (7) is 12.577126
# Euclidean distance from linked is 13.118364
# Euclidean distance from 7462 is 13.062203
# Euclidean distance from Patil_Siddhant_Vitthal is 12.104004
# Euclidean distance from 154936 is 12.009186
# Euclidean distance from Arjun picv is 12.721139
# Euclidean distance from Bharat is 13.026277
# Euclidean distance from Ankit Goyal is 12.157663
# Euclidean distance from Solanki is 11.738806
# Euclidean distance from Subhankar Pati(Bangalore) is 11.983671
# Euclidean distance from Abhijeet.Tarale Bangalore is 12.023133
# Euclidean distance from 101436 is 11.145995
# Euclidean distance from Yaramala.Spandana(Bangalore) is 12.169784
# Euclidean distance from IMG-20190530-WA0009 is 11.601988
# Euclidean distance from Osheen is 13.076878
# Euclidean distance from New Doc 2018-10-10 12.30.31 (6) is 12.577126
# Euclidean distance from Kamal is 12.790004
# Euclidean distance from ArchID is 12.155512
# Euclidean distance from New Doc 2018-10-01 18.22.44 (8) is 11.447719
# Euclidean distance from Image  is 12.61795
# Euclidean distance from Pooja Sharma is 11.995168
# Euclidean distance from Vijay Mannur is 11.702876
# Euclidean distance from MANGALEKAR is 11.839141
# Euclidean distance from AkankshaJoshi is 12.044389
# Euclidean distance from engineering-1547745743836 is 11.434551
# Euclidean distance from 2018-09-05-20-55-01-852 is 13.262331
# Euclidean distance from Neelesh Yadav Bangalore is 11.93455
# Euclidean distance from NidhiJain(Banglore) is 12.892766
# Euclidean distance from photo-1553354936430 is 10.495299
# Euclidean distance from varghese is 12.709452
# Euclidean distance from formal pic is 11.005876
# Euclidean distance from Nazmeen copy is 11.572134
# Euclidean distance from 00 is 12.256884
# Euclidean distance from 7619 is 12.7043705
# Euclidean distance from AqibImage - Copy is 12.528267
# Euclidean distance from prakshal is 12.712015
# Euclidean distance from Photograph is 11.760867
# Euclidean distance from KabirSachdevImage is 12.604496
# Euclidean distance from 59.152.53.203(optimized) is 12.963916
# Euclidean distance from shrutichoudhari is 10.954671
# Euclidean distance from 20190816_082257 is 11.569831
# Euclidean distance from 7008 is 12.1338215
# Euclidean distance from ramkumar is 12.797128
# Euclidean distance from swaroop is 11.628734
# Euclidean distance from passport size photo - Mudita Sisodia is 12.51095
# Euclidean distance from 20190703_154159 is 11.441119
# Euclidean distance from karan photo is 12.471301
# Euclidean distance from Shashwath is 12.895129
# Euclidean distance from Vridhi Shah is 12.938297
# Euclidean distance from Divya Pascal (Bangalore) is 11.852219
# Euclidean distance from picture is 12.47
# Euclidean distance from Shekhar Bhalsing is 11.79198
# Euclidean distance from AravindMenon(Bangalore) is 11.782311
# Euclidean distance from Karukonda_Nikhil_Reddy(Bangalore) is 11.950482
# Euclidean distance from Passport Pic is 13.635436
# Euclidean distance from IMG-20161121-WA0046 is 11.846878
# Euclidean distance from o is 11.954425
# Euclidean distance from Mokshadayini Narsule is 12.87893
# Euclidean distance from Shubhada-Padwal-Passport-Photo-1 is 12.57399
# Euclidean distance from Bhavesh is 11.982253
# Euclidean distance from 9809e056-4973-4a95-a2ea-7f6909afaf7b is 13.076878
# Euclidean distance from New Doc 2018-10-01 18.22.44 (6) is 11.447719
# Euclidean distance from AyushBahuguna(Bangalore) is 10.047889
# Euclidean distance from Amit_Deshwal_SD is 11.6226015
# Euclidean distance from DSC0051 copy 2 is 12.721164
# Euclidean distance from New Doc 2019-05-29 10.40.02 is 12.778102
# Euclidean distance from 1.PHOTO is 12.252554
# Euclidean distance from Photo-1 is 12.203636
# Euclidean distance from AkshayWagh is 10.767215
# Euclidean distance from download is 12.624735
# Euclidean distance from New Doc 2018-10-01 18.22.44 (1) is 11.447719
# Euclidean distance from New Doc 2018-09-30 21.25.49 is 11.588291
# Euclidean distance from KaustubhMaheshKhavnekar is 12.950491
# Euclidean distance from photo-1 is 12.818339
# Euclidean distance from 115429 is 10.92582
# Euclidean distance from IMG_20171029_143708_01_01_01 is 12.849824
# Euclidean distance from viewer is 13.206214
# Euclidean distance from 165154-min is 12.219871
# Euclidean distance from Tejas_20Ved is 12.3671255
# Euclidean distance from Palash is 12.076375
# Euclidean distance from 234041 is 12.766247
# Euclidean distance from 8thsep is 11.711229
# Euclidean distance from Sumi Neogi is 12.190771
# Euclidean distance from Khyati_20Parashar is 13.356004
# Euclidean distance from Abhishek Patra, Bangalore is 11.21365
# Time Taken :  0.0772860050201416
